# %%
from os import walk
from os.path import join

import pandas as pd
import matplotlib.pyplot as plt

import nltk
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from bs4 import BeautifulSoup
import numpy as np

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
EXAMPLE_FILE = 'SpamData/01_Processing/practice_email.txt'

SPAM_1_PATH = 'SpamData/01_Processing/spam_assassin_corpus/spam_1'
SPAM_2_PATH = 'SpamData/01_Processing/spam_assassin_corpus/spam_2'

EASY_NONSPAM_1_PATH = 'SpamData/01_Processing/spam_assassin_corpus/easy_ham_1'
EASY_NONSPAM_2_PATH = 'SpamData/01_Processing/spam_assassin_corpus/easy_ham_2'

SPAM_CAT = 1
HAM_CAT = 0
VOCAB_SIZE = 2500

DATA_JSON_FILE = 'SpamData/01_Processing/email-text-data.json'
WORD_ID_FILE = 'SpamData/01_Processing/word-by-id.csv'

TRAINING_DATA_FILE = 'SpamData/02_Training/train-data.txt'
TEST_DATA_FILE = 'SpamData/02_Training/test-data.txt'

WHALE_FILE = 'SpamData/01_Processing/wordcloud_resources/whale-icon.png'
SKULL_FILE = 'SpamData/01_Processing/wordcloud_resources/skull-icon.png'
THUMBS_UP_FILE = 'SpamData/01_Processing/wordcloud_resources/thumbs-up.png'
THUMBS_DOWN_FILE = 'SpamData/01_Processing/wordcloud_resources/thumbs-down.png'
CUSTOM_FONT_FILE = 'SpamData/01_Processing/wordcloud_resources/OpenSansCondensed-Bold.ttf'

# %% [markdown]
# ## Email body extraction

# %%
stream = open(EXAMPLE_FILE, encoding='latin-1')

is_body = False
lines = []

for line in stream:
    if is_body:
        lines.append(line)
    elif line == '\n':
        is_body = True

stream.close()

email_body = '\n'.join(lines)
print(email_body)
# Out:
# Dear Mr Still
#
#
#
# Good tidings to you and all your staff for the festive season ahead (Christmas).
#
# Now to the crux of the matter-in-hand: I am a fully qualified Santa Claus and am wondering whether you might consider me to run my own "Santa's Grotto" in your store.
#
# But WAIT! You're probably thinking: "What makes him so special?"
#
# Well, first of all, I have made several changes to the characterisation of Father Christmas. Rather than greeting the children with shouts of "Ho, ho, ho!" I prefer to whisper the phrase "Dependence is not unfathomable in this cruel world we live in". In addition, my gifts are ALL hand-made, ranging from felt hoops to vanilla-pod holders.
#
# You will note also, from the enclosed sketch, that I have radically redesigned Santa's outfit and have renamed my character "Lord Buckles". Would you be interested in employing me? I promise NEVER to let you down.
#
# I look forward to hearing from you.
#
#
#
# Best wishes
#
# Robin Cooper
#
# [Excerpt from the book: The Timewaster Letters by Robin Cooper]

# %%
def email_body_generator(path):
    
    for root, dirnames, filenames in walk(path):
        for file_name in filenames:
            
            filepath = join(root, file_name)
            
            stream = open(filepath, encoding='latin-1')

            is_body = False
            lines = []

            for line in stream:
                if is_body:
                    lines.append(line)
                elif line == '\n':
                    is_body = True

            stream.close()

            email_body = '\n'.join(lines)
            
            yield file_name, email_body

# %%
def df_from_directory(path, classification):
    rows = []
    row_names = []
    
    for file_name, email_body in email_body_generator(path):
        rows.append({'MESSAGE': email_body, 'CATEGORY': classification})
        row_names.append(file_name)
        
    return pd.DataFrame(rows, index=row_names)

# %%
spam_emails = df_from_directory(SPAM_1_PATH, 1)
spam_emails = spam_emails.append(df_from_directory(SPAM_2_PATH, 1))
spam_emails.head()
# Out:
#                                         CATEGORY  \
# 00170.33a973aa9bb7d122bdfbd96d44332996         1
# 00180.13a95a2542a0fd01ff24303561cca949         1
# 00201.00020fc9911604f6cae7ae0f598ad29d         1
# 00452.ed43fc952c31c82aa29646edfbecb03f         1
# 00286.efd0b8f0c9c779b7a0ad93505c9b0bae         1
#
#                                                                                   MESSAGE
# 00170.33a973aa9bb7d122bdfbd96d44332996  INTEREST RATES HAVE JUST BEEN CUT!!!\n\n     \...
# 00180.13a95a2542a0fd01ff24303561cca949  ------=_NextPart_000_00A5_78C83A6B.A1543A16\n\...
# 00201.00020fc9911604f6cae7ae0f598ad29d  <html>\n\n\n\n\n\n\n\n<body>\n\n\n\n<div align...
# 00452.ed43fc952c31c82aa29646edfbecb03f  IMPORTANT DOMAIN INFORMATION:\n\n\n\n\n\nThe n...
# 00286.efd0b8f0c9c779b7a0ad93505c9b0bae  <HTML>\n\n<head>\n\n<META HTTP-EQUIV="Content-...

# %%
spam_emails.shape
# Out:
# (1898, 2)

# %%
ham_emails = df_from_directory(EASY_NONSPAM_1_PATH, HAM_CAT)
ham_emails = ham_emails.append(df_from_directory(EASY_NONSPAM_2_PATH, HAM_CAT))
ham_emails.shape
# Out:
# (3901, 2)

# %%
data = pd.concat([spam_emails, ham_emails])
data.head()
# Out:
#                                         CATEGORY  \
# 00170.33a973aa9bb7d122bdfbd96d44332996         1
# 00180.13a95a2542a0fd01ff24303561cca949         1
# 00201.00020fc9911604f6cae7ae0f598ad29d         1
# 00452.ed43fc952c31c82aa29646edfbecb03f         1
# 00286.efd0b8f0c9c779b7a0ad93505c9b0bae         1
#
#                                                                                   MESSAGE
# 00170.33a973aa9bb7d122bdfbd96d44332996  INTEREST RATES HAVE JUST BEEN CUT!!!\n\n     \...
# 00180.13a95a2542a0fd01ff24303561cca949  ------=_NextPart_000_00A5_78C83A6B.A1543A16\n\...
# 00201.00020fc9911604f6cae7ae0f598ad29d  <html>\n\n\n\n\n\n\n\n<body>\n\n\n\n<div align...
# 00452.ed43fc952c31c82aa29646edfbecb03f  IMPORTANT DOMAIN INFORMATION:\n\n\n\n\n\nThe n...
# 00286.efd0b8f0c9c779b7a0ad93505c9b0bae  <HTML>\n\n<head>\n\n<META HTTP-EQUIV="Content-...

# %% [markdown]
# # Check for missing values

# %%
# check if there are empty emails (string length zero)
(data.MESSAGE.str.len() == 0).any()
# Out:
# True

# %%
(data.MESSAGE.str.len() == 0).sum()
# Out:
# 3

# %%
data.MESSAGE.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Locate empty emails

# %%
type(data.MESSAGE.str.len() == 0)
# Out:
# pandas.core.series.Series

# %%
data[data.MESSAGE.str.len() == 0].index
# Out:
# Index(['cmds', 'cmds', 'cmds'], dtype='object')

# %%
data.index.get_loc('cmds')
# Out:
# array([False, False, False, ..., False, False, False])

# %%
data.drop(['cmds'], inplace=True)

# %%
data.shape
# Out:
# (5796, 2)

# %% [markdown]
# # Add Document IDs to Track Emails in Dataset

# %%
document_ids = range(0, len(data.index))
data['DOC_ID'] = document_ids

# %%
data['FILE_NAME'] = data.index
data.set_index('DOC_ID', inplace=True)
data.head()
# Out:
#         CATEGORY                                            MESSAGE  \
# DOC_ID
# 0              1  INTEREST RATES HAVE JUST BEEN CUT!!!\n\n     \...
# 1              1  ------=_NextPart_000_00A5_78C83A6B.A1543A16\n\...
# 2              1  <html>\n\n\n\n\n\n\n\n<body>\n\n\n\n<div align...
# 3              1  IMPORTANT DOMAIN INFORMATION:\n\n\n\n\n\nThe n...
# 4              1  <HTML>\n\n<head>\n\n<META HTTP-EQUIV="Content-...
#
#                                      FILE_NAME
# DOC_ID
# 0       00170.33a973aa9bb7d122bdfbd96d44332996
# 1       00180.13a95a2542a0fd01ff24303561cca949
# 2       00201.00020fc9911604f6cae7ae0f598ad29d
# 3       00452.ed43fc952c31c82aa29646edfbecb03f
# 4       00286.efd0b8f0c9c779b7a0ad93505c9b0bae

# %%
data.tail()
# Out:
#         CATEGORY                                            MESSAGE  \
# DOC_ID
# 5791           0  Hobos in the depression used to use this techn...
# 5792           0   _   _ _____ _  __ <*the* weekly high-tech sar...
# 5793           0  Don't know if everybody knows this trick...\n\...
# 5794           0  http://docs.freebsd.org/cgi/getmsg.cgi?fetch=3...
# 5795           0  This is a multi-part message in MIME format.\n...
#
#                                      FILE_NAME
# DOC_ID
# 5791    00785.ba3a0a9d41b06b7fd1ea6025a417dfd1
# 5792    01389.e4cfb234aace4e12b2d9453686c911c9
# 5793    00961.404a92dc1c29461b711f0df8e96bbe90
# 5794    00205.1b7b16facf48373401d78996a92f6666
# 5795    01324.23a1f5017a5531fca08d9ebe2f5b0537

# %%
data.CATEGORY.value_counts()
# Out:
# 0    3900
# 1    1896
# Name: CATEGORY, dtype: int64

# %%
amount_of_spam = data.CATEGORY.value_counts()[1]
amount_of_ham = data.CATEGORY.value_counts()[0]

# %% [markdown]
# # Natural Language Processing

# %%
stop_words = set(stopwords.words('english'))

# %% [markdown]
# ## Functions for Email Processing

# %%
def clean_message(message, stemmer=PorterStemmer(),stop_words=set(stopwords.words('english'))):
    
    # Converts to Lower Case and splits up the words
    words = word_tokenize(message.lower())
    
    filtered_words = []
    
    for word in words:
        # Removes the stop words and punctuation
        if word not in stop_words and word.isalpha():
            filtered_words.append(stemmer.stem(word))
    
    return filtered_words

# %%
# Challenge: Modify function to remove HTML tags. Then test on Email with DOC_ID 2. 
def clean_msg_no_html(message, stemmer=PorterStemmer(), 
                 stop_words=set(stopwords.words('english'))):
    
    # Remove HTML tags
    soup = BeautifulSoup(message, 'html.parser')
    cleaned_text = soup.get_text()
    
    # Converts to Lower Case and splits up the words
    words = word_tokenize(cleaned_text.lower())
    
    filtered_words = []
    
    for word in words:
        # Removes the stop words and punctuation
        if word not in stop_words and word.isalpha():
            filtered_words.append(stemmer.stem(word))
#             filtered_words.append(word) 
    
    return filtered_words

# %% [markdown]
# # Generate Vocabulary & Dictionary

# %%
stemmed_nested_list = data.MESSAGE.apply(clean_msg_no_html)
# Out:
# /home/midhun/anaconda3/lib/python3.7/site-packages/bs4/__init__.py:335: UserWarning: "http://www.post-gazette.com/columnists/20020905brian5
# " looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup

# %%
type(stemmed_nested_list)
# Out:
# pandas.core.series.Series

# %%
stemmed_nested_list.head()
# Out:
# DOC_ID
# 0    [interest, rate, cut, perfect, time, think, re...
# 1                                                   []
# 2    [copi, dvd, burner, dvd, wizard, technolog, ad...
# 3    [import, domain, inform, new, domain, name, fi...
# 4    [free, info, free, insid, stock, market, repor...
# Name: MESSAGE, dtype: object

# %%
flat_stemmed_list = [item for sublist in stemmed_nested_list for item in sublist]
flat_stemmed_list
# Out:
# ['interest',
#  'rate',
#  'cut',
#  'perfect',
#  'time',
#  'think',
#  'refinanc',
#  'home',
#  'mortgag',
#  'rate',
#  'take',
#  'minut',
#  'fill',
#  'quick',
#  'onlin',
#  'form',
#  'http',
#  'easi',
#  'qualifi',
#  'prompt',
#  'courteou',
#  'servic',
#  'low',
#  'rate',
#  'wait',
#  'interest',
#  'rate',
#  'go',
#  'lock',
#  'low',
#  'rate',
#  'unsubscrib',
#  'go',
#  'http',
#  'pleas',
#  'allow',
#  'hour',
#  'remov',
#  'copi',
#  'dvd',
#  'burner',
#  'dvd',
#  'wizard',
#  'technolog',
#  'advanc',
#  'method',
#  'dvd',
#  'reproduct',
#  'ever',
#  'ble',
#  'fool',
#  'fli',
#  'night',
#  'websit',
#  'offer',
#  'outdat',
#  'inform',
#  'packag',
#  'show',
#  'b',
#  'backup',
#  'dvd',
#  'vh',
#  'cassett',
#  'use',
#  'burner',
#  'go',
#  'show',
#  'backup',
#  'dvd',
#  'use',
#  'burner',
#  'well',
#  'make',
#  'qualiti',
#  'backup',
#  'person',
#  'dvd',
#  'vh',
#  'cassett',
#  'creat',
#  'dvd',
#  'librari',
#  'never',
#  'worri',
#  'scratch',
#  'lose',
#  'dvd',
#  'dvd',
#  'wizard',
#  'pro',
#  'complet',
#  'unlik',
#  'anyth',
#  'titor',
#  'offer',
#  'fulli',
#  'guarante',
#  'order',
#  'today',
#  'wo',
#  'disappoint',
#  'limit',
#  'time',
#  'sold',
#  'packag',
#  'much',
#  'limit',
#  'ime',
#  'offer',
#  'instant',
#  'access',
#  'go',
#  'order',
#  'copi',
#  'today',
#  'email',
#  'address',
#  'obtain',
#  'list',
#  'mrsa',
#  'list',
#  'purchas',
#  'code',
#  'wish',
#  'subscrib',
#  'list',
#  'pleas',
#  'click',
#  'press',
#  'send',
#  'e',
#  'remov',
#  'previous',
#  'unsubscrib',
#  'still',
#  'receiv',
#  'messag',
#  'may',
#  'email',
#  'spam',
#  'abus',
#  'control',
#  'center',
#  'condon',
#  'spam',
#  'shape',
#  'form',
#  'thank',
#  'kindli',
#  'tion',
#  'import',
#  'domain',
#  'inform',
#  'new',
#  'domain',
#  'name',
#  'final',
#  'avail',
#  'gener',
#  'public',
#  'discount',
#  'price',
#  'regist',
#  'one',
#  'excit',
#  'new',
#  'domain',
#  'name',
#  'well',
#  'origin',
#  'name',
#  'brand',
#  'new',
#  'domain',
#  'extens',
#  'recent',
#  'approv',
#  'icann',
#  'right',
#  'origin',
#  'domain',
#  'name',
#  'biggest',
#  'benefit',
#  'domain',
#  'name',
#  'current',
#  'avail',
#  'much',
#  'easier',
#  'regist',
#  'attract',
#  'domain',
#  'name',
#  'price',
#  'visit',
#  'http',
#  'today',
#  'info',
#  'regist',
#  'domain',
#  'name',
#  'today',
#  'http',
#  'registr',
#  'fee',
#  'includ',
#  'full',
#  'access',
#  'control',
#  'panel',
#  'manag',
#  'domain',
#  'name',
#  'futur',
#  'sincer',
#  'domain',
#  'administr',
#  'domain',
#  'everyon',
#  'remov',
#  'email',
#  'address',
#  'promot',
#  'mail',
#  'compani',
#  'click',
#  'http',
#  'irish',
#  'linux',
#  'user',
#  'group',
#  'social',
#  'event',
#  'social',
#  'http',
#  'un',
#  'subscript',
#  'inform',
#  'list',
#  'maintain',
#  'listmast',
#  'free',
#  'info',
#  'free',
#  'insid',
#  'stock',
#  'market',
#  'report',
#  'valu',
#  'get',
#  'latest',
#  'competit',
#  'intellig',
#  'insid',
#  'knowledg',
#  'contact',
#  'stay',
#  'ahead',
#  'succeed',
#  'supercharg',
#  'market',
#  'free',
#  'month',
#  'subscript',
#  'subscrib',
#  'invest',
#  'banker',
#  'ventur',
#  'capitalist',
#  'fund',
#  'manag',
#  'public',
#  'compani',
#  'ceo',
#  'world',
#  'market',
#  'overview',
#  'updat',
#  'first',
#  'seen',
#  'analyst',
#  'report',
#  'invest',
#  'alert',
#  'portfolio',
#  'strategi',
#  'centuri',
#  'annual',
#  'offshor',
#  'jurisdict',
#  'rank',
#  'report',
#  'get',
#  'inform',
#  'profession',
#  'profit',
#  'fill',
#  'form',
#  'free',
#  'subscript',
#  'credit',
#  'card',
#  'need',
#  'sorri',
#  'see',
#  'go',
#  'unsubscrib',
#  'newslett',
#  'complet',
#  'follow',
#  'email',
#  'address',
#  'pleas',
#  'rememb',
#  'must',
#  'year',
#  'age',
#  'older',
#  'first',
#  'name',
#  'last',
#  'name',
#  'address',
#  'postal',
#  'zip',
#  'code',
#  'samoaandorraangolaanguillaantarcticaantigua',
#  'barbudaargentinaarmeniaarubaaustraliaaustriaazerbaijanbahamasbahrainbangladeshbarbadosbelarusbelgiumbelizebeninbermudabhutanboliviabosniabotswanabouvet',
#  'islandbrazilbritish',
#  'ocean',
#  'territorybritish',
#  'virgin',
#  'islesbruneibulgariaburkina',
#  'fasoburmaburundicambodiacamerooncap',
#  'verdecayman',
#  'islandscentr',
#  'african',
#  'islandcoco',
#  'islandsc',
#  'olombiacomoroscongocook',
#  'islandscosta',
#  'ricacroatiacyprusczech',
#  'republicdenmarkdjiboutidominicadominican',
#  'republiceast',
#  'timorecuadoregyptel',
#  'salvadorequatori',
#  'guineaeritreaestoniaethiopiafalkland',
#  'islandsfaro',
#  'islandsfijifinlandfrancefrench',
#  'guianafrench',
#  'polynesiafrench',
#  'southerngabongambiageorgiagermanyghanagibraltargreecegreenlan',
#  'mcdonald',
#  'isleshondurashong',
#  'konghungaryicelandindiaindonesiairelandisraelitalyivori',
#  'coastjamaicajapanjordankazakhstankenyakiribatikorea',
#  'southkuwaitkyrgyzstanlaoslatvialebanonlesotholiberialiechtensteinlithuanialuxembourgmacaumacedoniamadagascarmalawimalaysiamaldivesmalimaltamarshal',
#  'islandsmartiniquemauritaniamauritiusmayottemexicomicronesiamoldovamonacomongoliamontserratmoroccomozambiquenamibianaurunepalnetherlandsnetherland',
#  'antillesnew',
#  'caledonianew',
#  'zealandnicaraguanigernigerianiuenorfolk',
#  'islandnorthern',
#  'mariana',
#  'islandsnorwayomanpaki',
#  'tanpalaupanamapapua',
#  'new',
#  'guineaparaguayperuphilippinespitcairn',
#  'islandpolandportugalpuerto',
#  'islessaint',
#  'kitt',
#  'amp',
#  'nevissaint',
#  'luciasaint',
#  'vincentsamoasan',
#  'marinosao',
#  'tome',
#  'principesaudi',
#  'arabiasenegalseychellessierra',
#  'leonesingaporeslovakiasloveniasomaliasouth',
#  'africaspainsri',
#  'lanka',
#  'helenast',
#  'pierr',
#  'miquelonsurinamesvalbardswazilandswedenswitzerlandtaiwantajikistantanzaniathailandtogotokelautongatrinidad',
#  'tobagotunisiaturkeyturkmenistanturk',
#  'caico',
#  'minor',
#  'outli',
#  'islandsugandaukraineunit',
#  'arab',
#  'emiratesunit',
#  'kingdomuruguayuzbekistanvanuatuvatican',
#  'cityvenezuelavietnamvirgin',
#  'islandsw',
#  'futuna',
#  'islandsw',
#  'estern',
#  'saharayemenyugoslavia',
#  'former',
#  'zairezambiazimbabwetelephon',
#  'work',
#  'email',
#  'address',
#  'requir',
#  'field',
#  'v',
#  'messag',
#  'mime',
#  'format',
#  'webxpert',
#  'design',
#  'build',
#  'internet',
#  'bodi',
#  'verdana',
#  'color',
#  'white',
#  'td',
#  'verdana',
#  'color',
#  'white',
#  'verdana',
#  'color',
#  'cccccc',
#  'hover',
#  'verdana',
#  'color',
#  'yellow',
#  'flyer',
#  'appear',
#  'correctli',
#  'imag',
#  'appear',
#  'pleas',
#  'click',
#  'follow',
#  'link',
#  'http',
#  'email',
#  'address',
#  'obtain',
#  'purchas',
#  'list',
#  'receiv',
#  'eluxmedia',
#  'llc',
#  'part',
#  'mail',
#  'list',
#  'wish',
#  'unsubscrib',
#  'list',
#  'pleas',
#  'click',
#  'enter',
#  'name',
#  'remov',
#  'previous',
#  'unsubscrib',
#  'still',
#  'receiv',
#  'messag',
#  'may',
#  'email',
#  'abus',
#  'control',
#  'center',
#  'copyright',
#  'right',
#  'reservedif',
#  'would',
#  'longer',
#  'ike',
#  'us',
#  'contact',
#  'feel',
#  'havereceiv',
#  'email',
#  'pleas',
#  'k',
#  'unsubscrib',
#  'team',
#  'foundmoney',
#  'help',
#  'locat',
#  'claim',
#  'lost',
#  'cash',
#  'amount',
#  'check',
#  'liter',
#  'claim',
#  'contest',
#  'promot',
#  'foundmoney',
#  'search',
#  'servic',
#  'dedic',
#  'put',
#  'unclaim',
#  'money',
#  'togeth',
#  'right',
#  'owner',
#  'million',
#  'north',
#  'american',
#  'peopl',
#  'elig',
#  'right',
#  'claim',
#  'unknown',
#  'cash',
#  'windfal',
#  'search',
#  'fast',
#  'easi',
#  'gaurante',
#  'billion',
#  'sit',
#  'databas',
#  'alon',
#  'contain',
#  'bank',
#  'govern',
#  'account',
#  'will',
#  'estat',
#  'insur',
#  'settlement',
#  'etc',
#  'sinc',
#  'web',
#  'site',
#  'reunit',
#  'million',
#  'upon',
#  'million',
#  'dollar',
#  'thousand',
#  'right',
#  'owner',
#  'even',
#  'know',
#  'money',
#  'wait',
#  'click',
#  'link',
#  'find',
#  'second',
#  'money',
#  'wait',
#  'claim',
#  'famili',
#  'name',
#  'somebodi',
#  'know',
#  'initi',
#  'search',
#  'free',
#  'noth',
#  'lose',
#  'tri',
#  'foundmoney',
#  'today',
#  'click',
#  'sincer',
#  'receiv',
#  'email',
#  'sign',
#  'one',
#  'websit',
#  'sign',
#  'parti',
#  'contract',
#  'unsubscrib',
#  'email',
#  'newslett',
#  'pleas',
#  'visit',
#  'http',
#  'dear',
#  'stuart',
#  'tire',
#  'search',
#  'love',
#  'wrong',
#  'place',
#  'find',
#  'love',
#  'http',
#  'brows',
#  'thousand',
#  'person',
#  'area',
#  'join',
#  'free',
#  'http',
#  'search',
#  'chat',
#  'use',
#  'meet',
#  'cool',
#  'guy',
#  'hot',
#  'girl',
#  'go',
#  'use',
#  'privat',
#  'chat',
#  'room',
#  'click',
#  'link',
#  'get',
#  'start',
#  'http',
#  'find',
#  'love',
#  'receiv',
#  'email',
#  'registerd',
#  'emailrewardz',
#  'subscrib',
#  'one',
#  'market',
#  'partner',
#  'receiv',
#  'messag',
#  'error',
#  'wish',
#  'stop',
#  'receiv',
#  'great',
#  'offer',
#  'pleas',
#  'click',
#  'remov',
#  'link',
#  'unsubscrib',
#  'mail',
#  'pleas',
#  'click',
#  'http',
#  'emailrewardz',
#  'never',
#  'send',
#  'unsolicit',
#  'email',
#  'receiv',
#  'messag',
#  'request',
#  'receiv',
#  'special',
#  'offer',
#  'affili',
#  'emailrewardz',
#  'emailrewardz',
#  'bring',
#  'highest',
#  'qualiti',
#  'offer',
#  'privaci',
#  'guarante',
#  'longer',
#  'wish',
#  'receiv',
#  'offer',
#  'pleas',
#  'follow',
#  'instruct',
#  'bottom',
#  'messag',
#  'meet',
#  'singl',
#  'like',
#  'tire',
#  'search',
#  'love',
#  'wrong',
#  'place',
#  'find',
#  'love',
#  'easi',
#  'way',
#  'join',
#  'freefind',
#  'soul',
#  'mate',
#  'today',
#  'brows',
#  'thousand',
#  'person',
#  'area',
#  'click',
#  'hereto',
#  'find',
#  'love',
#  'receiv',
#  'email',
#  'regist',
#  'emailrewardz',
#  'subscrib',
#  'one',
#  'market',
#  'partner',
#  'receiv',
#  'messag',
#  'error',
#  'wish',
#  'stop',
#  'receiv',
#  'great',
#  'offer',
#  'pleas',
#  'read',
#  'remov',
#  'instruct',
#  'click',
#  'unsubscrib',
#  'mail',
#  'lose',
#  'weight',
#  'build',
#  'lean',
#  'muscl',
#  'mass',
#  'revers',
#  'ravag',
#  'age',
#  'man',
#  'growth',
#  'hormon',
#  'therapi',
#  'lose',
#  'ight',
#  'build',
#  'lean',
#  'muscl',
#  'mass',
#  'revers',
#  'ravag',
#  'age',
#  'discoveri',
#  'human',
#  'growth',
#  'hormon',
#  'hgh',
#  'ing',
#  'way',
#  'think',
#  'age',
#  'weight',
#  'loss',
#  'lose',
#  'weight',
#  'build',
#  'muscl',
#  'tone',
#  'revers',
#  'age',
#  'increas',
#  'libido',
#  'durat',
#  'penil',
#  'erect',
#  'new',
#  'hair',
#  'growth',
#  'improv',
#  'memori',
#  'improv',
#  'skin',
#  'new',
#  'hair',
#  'growth',
#  'wrinkl',
#  'disappear',
#  'visit',
#  'web',
#  'site',
#  'lean',
#  'fact',
#  'click',
#  'opportun',
#  'knock',
#  'mortgag',
#  'rate',
#  'rise',
#  'nation',
#  'lender',
#  'broker',
#  'guarante',
#  'lowest',
#  'possibl',
#  'rate',
#  'home',
#  'loan',
#  'rate',
#  'may',
#  'well',
#  'never',
#  'low',
#  'chanc',
#  'secur',
#  'better',
#  'futur',
#  'could',
#  'liter',
#  'save',
#  'enough',
#  'money',
#  'buy',
#  'new',
#  'car',
#  'want',
#  'take',
#  'special',
#  'vacat',
#  'pay',
#  'pay',
#  'guarante',
#  'best',
#  'rate',
#  'best',
#  'deal',
#  'possibl',
#  'act',
#  'free',
#  'servic',
#  'fee',
#  'kind',
#  'easili',
#  'determin',
#  'help',
#  'short',
#  'minut',
#  'provid',
#  'inform',
#  'term',
#  'simpl',
#  'anyon',
#  'understand',
#  'promis',
#  'wo',
#  'need',
#  'attorney',
#  'see',
#  'save',
#  'offer',
#  'first',
#  'second',
#  'home',
#  'loan',
#  'happi',
#  'show',
#  'current',
#  'loan',
#  'best',
#  'replac',
#  'risk',
#  'none',
#  'take',
#  'two',
#  'minut',
#  'use',
#  'link',
#  'work',
#  'let',
#  'us',
#  'show',
#  'get',
#  'famili',
#  'let',
#  'opportun',
#  'pass',
#  'take',
#  'action',
#  'http',
#  'sincer',
#  'chalr',
#  'gillett',
#  'mortcorp',
#  'llc',
#  'rpmmumwnzvrmtuqepbremaddardmkkksfpipttmsdocbmnbkghfqauxdoitvxdmvdazpibikzbfxporvaazcuttzzzzjxuitoysdfbyominmypxtuomobktfgqg',
#  'new',
#  'netscap',
#  'browser',
#  'avail',
#  'upgrad',
#  'http',
#  'get',
#  'free',
#  'person',
#  'netscap',
#  'mail',
#  'account',
#  'today',
#  'http',
#  'repli',
#  'messag',
#  'remov',
#  'easi',
#  'remov',
#  'mail',
#  'list',
#  'pleas',
#  'click',
#  'http',
#  'email',
#  'sent',
#  'email',
#  'part',
#  'target',
#  'list',
#  'wish',
#  'receiv',
#  'mail',
#  'offer',
#  'pleas',
#  'click',
#  'enter',
#  'email',
#  'remov',
#  'email',
#  'futur',
#  'offer',
#  'beaton',
#  'enterpris',
#  'jefferson',
#  'street',
#  'zegema',
#  'beach',
#  'pa',
#  'comput',
#  'need',
#  'oil',
#  'chang',
#  'uter',
#  'need',
#  'oil',
#  'chang',
#  'ortonsystemwork',
#  'profession',
#  'edit',
#  'made',
#  'creator',
#  'softwar',
#  'market',
#  'unbeat',
#  'softwar',
#  'suit',
#  'come',
#  'everi',
#  'program',
#  'ever',
#  'eed',
#  'answer',
#  'problem',
#  'threat',
#  'comput',
#  'face',
#  'day',
#  'life',
#  'includ',
#  'magnific',
#  'deal',
#  'follow',
#  'program',
#  'norton',
#  'protecion',
#  'ever',
#  'norton',
#  'diagnos',
#  'problem',
#  'th',
#  'system',
#  'norton',
#  'make',
#  'back',
#  'valuabl',
#  'data',
#  'easi',
#  'norton',
#  'clean',
#  'excess',
#  'internet',
#  'file',
#  'buildup',
#  'norton',
#  'basic',
#  'turn',
#  'cpu',
#  'fax',
#  'machin',
#  'person',
#  'help',
#  'prevent',
#  'make',
#  ...]

# %%
type(flat_stemmed_list)
# Out:
# list

# %% [markdown]
# # Generate Features & a Sparse Matrix
#
# ### Creating a DataFrame with one Word per Column

# %%
unique_words = pd.Series(flat_stemmed_list).value_counts()
print('Nr of unique words', unique_words.shape[0])
print(unique_words.head())
print(type(unique_words))
# Out:
# Nr of unique words 27305
# http     10662
# use       5017
# list      4852
# email     4370
# get       4187
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
frequent_words = unique_words[0:2500]
print('Most common words: \n', frequent_words[:10])
# Out:
# Most common words:
#  http     10662
# use       5017
# list      4852
# email     4370
# get       4187
# mail      3985
# one       3905
# free      3171
# time      3090
# work      2880
# dtype: int64

# %%
type(stemmed_nested_list.tolist())
# Out:
# list

# %%
stemmed_nested_list.tolist()
# Out:
# [['interest',
#   'rate',
#   'cut',
#   'perfect',
#   'time',
#   'think',
#   'refinanc',
#   'home',
#   'mortgag',
#   'rate',
#   'take',
#   'minut',
#   'fill',
#   'quick',
#   'onlin',
#   'form',
#   'http',
#   'easi',
#   'qualifi',
#   'prompt',
#   'courteou',
#   'servic',
#   'low',
#   'rate',
#   'wait',
#   'interest',
#   'rate',
#   'go',
#   'lock',
#   'low',
#   'rate',
#   'unsubscrib',
#   'go',
#   'http',
#   'pleas',
#   'allow',
#   'hour',
#   'remov'],
#  [],
#  ['copi',
#   'dvd',
#   'burner',
#   'dvd',
#   'wizard',
#   'technolog',
#   'advanc',
#   'method',
#   'dvd',
#   'reproduct',
#   'ever',
#   'ble',
#   'fool',
#   'fli',
#   'night',
#   'websit',
#   'offer',
#   'outdat',
#   'inform',
#   'packag',
#   'show',
#   'b',
#   'backup',
#   'dvd',
#   'vh',
#   'cassett',
#   'use',
#   'burner',
#   'go',
#   'show',
#   'backup',
#   'dvd',
#   'use',
#   'burner',
#   'well',
#   'make',
#   'qualiti',
#   'backup',
#   'person',
#   'dvd',
#   'vh',
#   'cassett',
#   'creat',
#   'dvd',
#   'librari',
#   'never',
#   'worri',
#   'scratch',
#   'lose',
#   'dvd',
#   'dvd',
#   'wizard',
#   'pro',
#   'complet',
#   'unlik',
#   'anyth',
#   'titor',
#   'offer',
#   'fulli',
#   'guarante',
#   'order',
#   'today',
#   'wo',
#   'disappoint',
#   'limit',
#   'time',
#   'sold',
#   'packag',
#   'much',
#   'limit',
#   'ime',
#   'offer',
#   'instant',
#   'access',
#   'go',
#   'order',
#   'copi',
#   'today',
#   'email',
#   'address',
#   'obtain',
#   'list',
#   'mrsa',
#   'list',
#   'purchas',
#   'code',
#   'wish',
#   'subscrib',
#   'list',
#   'pleas',
#   'click',
#   'press',
#   'send',
#   'e',
#   'remov',
#   'previous',
#   'unsubscrib',
#   'still',
#   'receiv',
#   'messag',
#   'may',
#   'email',
#   'spam',
#   'abus',
#   'control',
#   'center',
#   'condon',
#   'spam',
#   'shape',
#   'form',
#   'thank',
#   'kindli',
#   'tion'],
#  ['import',
#   'domain',
#   'inform',
#   'new',
#   'domain',
#   'name',
#   'final',
#   'avail',
#   'gener',
#   'public',
#   'discount',
#   'price',
#   'regist',
#   'one',
#   'excit',
#   'new',
#   'domain',
#   'name',
#   'well',
#   'origin',
#   'name',
#   'brand',
#   'new',
#   'domain',
#   'extens',
#   'recent',
#   'approv',
#   'icann',
#   'right',
#   'origin',
#   'domain',
#   'name',
#   'biggest',
#   'benefit',
#   'domain',
#   'name',
#   'current',
#   'avail',
#   'much',
#   'easier',
#   'regist',
#   'attract',
#   'domain',
#   'name',
#   'price',
#   'visit',
#   'http',
#   'today',
#   'info',
#   'regist',
#   'domain',
#   'name',
#   'today',
#   'http',
#   'registr',
#   'fee',
#   'includ',
#   'full',
#   'access',
#   'control',
#   'panel',
#   'manag',
#   'domain',
#   'name',
#   'futur',
#   'sincer',
#   'domain',
#   'administr',
#   'domain',
#   'everyon',
#   'remov',
#   'email',
#   'address',
#   'promot',
#   'mail',
#   'compani',
#   'click',
#   'http',
#   'irish',
#   'linux',
#   'user',
#   'group',
#   'social',
#   'event',
#   'social',
#   'http',
#   'un',
#   'subscript',
#   'inform',
#   'list',
#   'maintain',
#   'listmast'],
#  ['free',
#   'info',
#   'free',
#   'insid',
#   'stock',
#   'market',
#   'report',
#   'valu',
#   'get',
#   'latest',
#   'competit',
#   'intellig',
#   'insid',
#   'knowledg',
#   'contact',
#   'stay',
#   'ahead',
#   'succeed',
#   'supercharg',
#   'market',
#   'free',
#   'month',
#   'subscript',
#   'subscrib',
#   'invest',
#   'banker',
#   'ventur',
#   'capitalist',
#   'fund',
#   'manag',
#   'public',
#   'compani',
#   'ceo',
#   'world',
#   'market',
#   'overview',
#   'updat',
#   'first',
#   'seen',
#   'analyst',
#   'report',
#   'invest',
#   'alert',
#   'portfolio',
#   'strategi',
#   'centuri',
#   'annual',
#   'offshor',
#   'jurisdict',
#   'rank',
#   'report',
#   'get',
#   'inform',
#   'profession',
#   'profit',
#   'fill',
#   'form',
#   'free',
#   'subscript',
#   'credit',
#   'card',
#   'need',
#   'sorri',
#   'see',
#   'go',
#   'unsubscrib',
#   'newslett',
#   'complet',
#   'follow',
#   'email',
#   'address',
#   'pleas',
#   'rememb',
#   'must',
#   'year',
#   'age',
#   'older',
#   'first',
#   'name',
#   'last',
#   'name',
#   'address',
#   'postal',
#   'zip',
#   'code',
#   'samoaandorraangolaanguillaantarcticaantigua',
#   'barbudaargentinaarmeniaarubaaustraliaaustriaazerbaijanbahamasbahrainbangladeshbarbadosbelarusbelgiumbelizebeninbermudabhutanboliviabosniabotswanabouvet',
#   'islandbrazilbritish',
#   'ocean',
#   'territorybritish',
#   'virgin',
#   'islesbruneibulgariaburkina',
#   'fasoburmaburundicambodiacamerooncap',
#   'verdecayman',
#   'islandscentr',
#   'african',
#   'islandcoco',
#   'islandsc',
#   'olombiacomoroscongocook',
#   'islandscosta',
#   'ricacroatiacyprusczech',
#   'republicdenmarkdjiboutidominicadominican',
#   'republiceast',
#   'timorecuadoregyptel',
#   'salvadorequatori',
#   'guineaeritreaestoniaethiopiafalkland',
#   'islandsfaro',
#   'islandsfijifinlandfrancefrench',
#   'guianafrench',
#   'polynesiafrench',
#   'southerngabongambiageorgiagermanyghanagibraltargreecegreenlan',
#   'mcdonald',
#   'isleshondurashong',
#   'konghungaryicelandindiaindonesiairelandisraelitalyivori',
#   'coastjamaicajapanjordankazakhstankenyakiribatikorea',
#   'southkuwaitkyrgyzstanlaoslatvialebanonlesotholiberialiechtensteinlithuanialuxembourgmacaumacedoniamadagascarmalawimalaysiamaldivesmalimaltamarshal',
#   'islandsmartiniquemauritaniamauritiusmayottemexicomicronesiamoldovamonacomongoliamontserratmoroccomozambiquenamibianaurunepalnetherlandsnetherland',
#   'antillesnew',
#   'caledonianew',
#   'zealandnicaraguanigernigerianiuenorfolk',
#   'islandnorthern',
#   'mariana',
#   'islandsnorwayomanpaki',
#   'tanpalaupanamapapua',
#   'new',
#   'guineaparaguayperuphilippinespitcairn',
#   'islandpolandportugalpuerto',
#   'islessaint',
#   'kitt',
#   'amp',
#   'nevissaint',
#   'luciasaint',
#   'vincentsamoasan',
#   'marinosao',
#   'tome',
#   'principesaudi',
#   'arabiasenegalseychellessierra',
#   'leonesingaporeslovakiasloveniasomaliasouth',
#   'africaspainsri',
#   'lanka',
#   'helenast',
#   'pierr',
#   'miquelonsurinamesvalbardswazilandswedenswitzerlandtaiwantajikistantanzaniathailandtogotokelautongatrinidad',
#   'tobagotunisiaturkeyturkmenistanturk',
#   'caico',
#   'minor',
#   'outli',
#   'islandsugandaukraineunit',
#   'arab',
#   'emiratesunit',
#   'kingdomuruguayuzbekistanvanuatuvatican',
#   'cityvenezuelavietnamvirgin',
#   'islandsw',
#   'futuna',
#   'islandsw',
#   'estern',
#   'saharayemenyugoslavia',
#   'former',
#   'zairezambiazimbabwetelephon',
#   'work',
#   'email',
#   'address',
#   'requir',
#   'field',
#   'v'],
#  ['messag',
#   'mime',
#   'format',
#   'webxpert',
#   'design',
#   'build',
#   'internet',
#   'bodi',
#   'verdana',
#   'color',
#   'white',
#   'td',
#   'verdana',
#   'color',
#   'white',
#   'verdana',
#   'color',
#   'cccccc',
#   'hover',
#   'verdana',
#   'color',
#   'yellow',
#   'flyer',
#   'appear',
#   'correctli',
#   'imag',
#   'appear',
#   'pleas',
#   'click',
#   'follow',
#   'link',
#   'http',
#   'email',
#   'address',
#   'obtain',
#   'purchas',
#   'list',
#   'receiv',
#   'eluxmedia',
#   'llc',
#   'part',
#   'mail',
#   'list',
#   'wish',
#   'unsubscrib',
#   'list',
#   'pleas',
#   'click',
#   'enter',
#   'name',
#   'remov',
#   'previous',
#   'unsubscrib',
#   'still',
#   'receiv',
#   'messag',
#   'may',
#   'email',
#   'abus',
#   'control',
#   'center'],
#  ['copyright',
#   'right',
#   'reservedif',
#   'would',
#   'longer',
#   'ike',
#   'us',
#   'contact',
#   'feel',
#   'havereceiv',
#   'email',
#   'pleas',
#   'k',
#   'unsubscrib'],
#  ['team',
#   'foundmoney',
#   'help',
#   'locat',
#   'claim',
#   'lost',
#   'cash',
#   'amount',
#   'check',
#   'liter',
#   'claim',
#   'contest',
#   'promot',
#   'foundmoney',
#   'search',
#   'servic',
#   'dedic',
#   'put',
#   'unclaim',
#   'money',
#   'togeth',
#   'right',
#   'owner',
#   'million',
#   'north',
#   'american',
#   'peopl',
#   'elig',
#   'right',
#   'claim',
#   'unknown',
#   'cash',
#   'windfal',
#   'search',
#   'fast',
#   'easi',
#   'gaurante',
#   'billion',
#   'sit',
#   'databas',
#   'alon',
#   'contain',
#   'bank',
#   'govern',
#   'account',
#   'will',
#   'estat',
#   'insur',
#   'settlement',
#   'etc',
#   'sinc',
#   'web',
#   'site',
#   'reunit',
#   'million',
#   'upon',
#   'million',
#   'dollar',
#   'thousand',
#   'right',
#   'owner',
#   'even',
#   'know',
#   'money',
#   'wait',
#   'click',
#   'link',
#   'find',
#   'second',
#   'money',
#   'wait',
#   'claim',
#   'famili',
#   'name',
#   'somebodi',
#   'know',
#   'initi',
#   'search',
#   'free',
#   'noth',
#   'lose',
#   'tri',
#   'foundmoney',
#   'today',
#   'click',
#   'sincer',
#   'receiv',
#   'email',
#   'sign',
#   'one',
#   'websit',
#   'sign',
#   'parti',
#   'contract',
#   'unsubscrib',
#   'email',
#   'newslett',
#   'pleas',
#   'visit',
#   'http'],
#  [],
#  ['dear',
#   'stuart',
#   'tire',
#   'search',
#   'love',
#   'wrong',
#   'place',
#   'find',
#   'love',
#   'http',
#   'brows',
#   'thousand',
#   'person',
#   'area',
#   'join',
#   'free',
#   'http',
#   'search',
#   'chat',
#   'use',
#   'meet',
#   'cool',
#   'guy',
#   'hot',
#   'girl',
#   'go',
#   'use',
#   'privat',
#   'chat',
#   'room',
#   'click',
#   'link',
#   'get',
#   'start',
#   'http',
#   'find',
#   'love',
#   'receiv',
#   'email',
#   'registerd',
#   'emailrewardz',
#   'subscrib',
#   'one',
#   'market',
#   'partner',
#   'receiv',
#   'messag',
#   'error',
#   'wish',
#   'stop',
#   'receiv',
#   'great',
#   'offer',
#   'pleas',
#   'click',
#   'remov',
#   'link',
#   'unsubscrib',
#   'mail',
#   'pleas',
#   'click',
#   'http',
#   'emailrewardz',
#   'never',
#   'send',
#   'unsolicit',
#   'email',
#   'receiv',
#   'messag',
#   'request',
#   'receiv',
#   'special',
#   'offer',
#   'affili',
#   'emailrewardz',
#   'emailrewardz',
#   'bring',
#   'highest',
#   'qualiti',
#   'offer',
#   'privaci',
#   'guarante',
#   'longer',
#   'wish',
#   'receiv',
#   'offer',
#   'pleas',
#   'follow',
#   'instruct',
#   'bottom',
#   'messag',
#   'meet',
#   'singl',
#   'like',
#   'tire',
#   'search',
#   'love',
#   'wrong',
#   'place',
#   'find',
#   'love',
#   'easi',
#   'way',
#   'join',
#   'freefind',
#   'soul',
#   'mate',
#   'today',
#   'brows',
#   'thousand',
#   'person',
#   'area',
#   'click',
#   'hereto',
#   'find',
#   'love',
#   'receiv',
#   'email',
#   'regist',
#   'emailrewardz',
#   'subscrib',
#   'one',
#   'market',
#   'partner',
#   'receiv',
#   'messag',
#   'error',
#   'wish',
#   'stop',
#   'receiv',
#   'great',
#   'offer',
#   'pleas',
#   'read',
#   'remov',
#   'instruct',
#   'click',
#   'unsubscrib',
#   'mail'],
#  ['lose',
#   'weight',
#   'build',
#   'lean',
#   'muscl',
#   'mass',
#   'revers',
#   'ravag',
#   'age',
#   'man',
#   'growth',
#   'hormon',
#   'therapi',
#   'lose',
#   'ight',
#   'build',
#   'lean',
#   'muscl',
#   'mass',
#   'revers',
#   'ravag',
#   'age',
#   'discoveri',
#   'human',
#   'growth',
#   'hormon',
#   'hgh',
#   'ing',
#   'way',
#   'think',
#   'age',
#   'weight',
#   'loss',
#   'lose',
#   'weight',
#   'build',
#   'muscl',
#   'tone',
#   'revers',
#   'age',
#   'increas',
#   'libido',
#   'durat',
#   'penil',
#   'erect',
#   'new',
#   'hair',
#   'growth',
#   'improv',
#   'memori',
#   'improv',
#   'skin',
#   'new',
#   'hair',
#   'growth',
#   'wrinkl',
#   'disappear',
#   'visit',
#   'web',
#   'site',
#   'lean',
#   'fact',
#   'click'],
#  ['opportun',
#   'knock',
#   'mortgag',
#   'rate',
#   'rise',
#   'nation',
#   'lender',
#   'broker',
#   'guarante',
#   'lowest',
#   'possibl',
#   'rate',
#   'home',
#   'loan',
#   'rate',
#   'may',
#   'well',
#   'never',
#   'low',
#   'chanc',
#   'secur',
#   'better',
#   'futur',
#   'could',
#   'liter',
#   'save',
#   'enough',
#   'money',
#   'buy',
#   'new',
#   'car',
#   'want',
#   'take',
#   'special',
#   'vacat',
#   'pay',
#   'pay',
#   'guarante',
#   'best',
#   'rate',
#   'best',
#   'deal',
#   'possibl',
#   'act',
#   'free',
#   'servic',
#   'fee',
#   'kind',
#   'easili',
#   'determin',
#   'help',
#   'short',
#   'minut',
#   'provid',
#   'inform',
#   'term',
#   'simpl',
#   'anyon',
#   'understand',
#   'promis',
#   'wo',
#   'need',
#   'attorney',
#   'see',
#   'save',
#   'offer',
#   'first',
#   'second',
#   'home',
#   'loan',
#   'happi',
#   'show',
#   'current',
#   'loan',
#   'best',
#   'replac',
#   'risk',
#   'none',
#   'take',
#   'two',
#   'minut',
#   'use',
#   'link',
#   'work',
#   'let',
#   'us',
#   'show',
#   'get',
#   'famili',
#   'let',
#   'opportun',
#   'pass',
#   'take',
#   'action',
#   'http',
#   'sincer',
#   'chalr',
#   'gillett',
#   'mortcorp',
#   'llc',
#   'rpmmumwnzvrmtuqepbremaddardmkkksfpipttmsdocbmnbkghfqauxdoitvxdmvdazpibikzbfxporvaazcuttzzzzjxuitoysdfbyominmypxtuomobktfgqg',
#   'new',
#   'netscap',
#   'browser',
#   'avail',
#   'upgrad',
#   'http',
#   'get',
#   'free',
#   'person',
#   'netscap',
#   'mail',
#   'account',
#   'today',
#   'http'],
#  ['repli',
#   'messag',
#   'remov',
#   'easi',
#   'remov',
#   'mail',
#   'list',
#   'pleas',
#   'click',
#   'http',
#   'email',
#   'sent',
#   'email',
#   'part',
#   'target',
#   'list',
#   'wish',
#   'receiv',
#   'mail',
#   'offer',
#   'pleas',
#   'click',
#   'enter',
#   'email',
#   'remov',
#   'email',
#   'futur',
#   'offer',
#   'beaton',
#   'enterpris',
#   'jefferson',
#   'street',
#   'zegema',
#   'beach',
#   'pa'],
#  ['comput',
#   'need',
#   'oil',
#   'chang',
#   'uter',
#   'need',
#   'oil',
#   'chang',
#   'ortonsystemwork',
#   'profession',
#   'edit',
#   'made',
#   'creator',
#   'softwar',
#   'market',
#   'unbeat',
#   'softwar',
#   'suit',
#   'come',
#   'everi',
#   'program',
#   'ever',
#   'eed',
#   'answer',
#   'problem',
#   'threat',
#   'comput',
#   'face',
#   'day',
#   'life',
#   'includ',
#   'magnific',
#   'deal',
#   'follow',
#   'program',
#   'norton',
#   'protecion',
#   'ever',
#   'norton',
#   'diagnos',
#   'problem',
#   'th',
#   'system',
#   'norton',
#   'make',
#   'back',
#   'valuabl',
#   'data',
#   'easi',
#   'norton',
#   'clean',
#   'excess',
#   'internet',
#   'file',
#   'buildup',
#   'norton',
#   'basic',
#   'turn',
#   'cpu',
#   'fax',
#   'machin',
#   'person',
#   'help',
#   'prevent',
#   'make',
#   'mistak',
#   'retail',
#   'price',
#   'get',
#   'free',
#   'ship',
#   'click',
#   'order',
#   'product',
#   'avail',
#   'run',
#   'gone',
#   'get',
#   'hot',
#   'email',
#   'address',
#   'obtain',
#   'list',
#   'iao',
#   'internet',
#   'advertis',
#   'organis',
#   'list',
#   'serial',
#   'wish',
#   'unsubscrib',
#   'rom',
#   'list',
#   'pleas',
#   'click',
#   'condon',
#   'spam',
#   'shape',
#   'form',
#   'thank',
#   'dli',
#   'cooper'],
#  ['mother',
#   'natur',
#   'natur',
#   'marit',
#   'aid',
#   'men',
#   'women',
#   'risk',
#   'free',
#   'natur',
#   'safe',
#   'formula',
#   'men',
#   'women',
#   'risk',
#   'free',
#   'day',
#   'mother',
#   'natur',
#   'wonder',
#   'pill',
#   'centuri',
#   'increas',
#   'sensationincreas',
#   'frequenc',
#   'increas',
#   'pleasureincreas',
#   'desir',
#   'increas',
#   'staminaincreas',
#   'libido',
#   'male',
#   'femal',
#   'formula',
#   'order',
#   'trial',
#   'today',
#   'depart',
#   'contact',
#   'visit',
#   'tbeyer'],
#  ['hand',
#   'select',
#   'access',
#   'exclus',
#   'inform',
#   'free',
#   'receiv',
#   'mail',
#   'member',
#   'subscrib',
#   'jm',
#   'unsubscrib',
#   'click',
#   'http',
#   'repli',
#   'email',
#   'remov',
#   'subject',
#   'line',
#   'must',
#   'also',
#   'includ',
#   'bodi',
#   'messag',
#   'unsubscrib',
#   'correspond',
#   'direct',
#   'compani',
#   'ad',
#   'em',
#   'jm'],
#  ['central',
#   'bank',
#   'nigeria',
#   'foreign',
#   'remitt',
#   'dept',
#   'tinubu',
#   'squar',
#   'lago',
#   'nigeria',
#   'august',
#   'attn',
#   'strictli',
#   'privat',
#   'busi',
#   'propos',
#   'abu',
#   'bill',
#   'exchang',
#   'director',
#   'foreignremitt',
#   'depart',
#   'central',
#   'bank',
#   'nigeria',
#   'writingy',
#   'letter',
#   'ask',
#   'support',
#   'cooper',
#   'carri',
#   'thisbusi',
#   'opportun',
#   'depart',
#   'discov',
#   'abandon',
#   'sumof',
#   'us',
#   'thirti',
#   'seven',
#   'million',
#   'four',
#   'hundr',
#   'thousand',
#   'unitedst',
#   'dollar',
#   'account',
#   'belong',
#   'one',
#   'foreign',
#   'custom',
#   'american',
#   'late',
#   'engr',
#   'john',
#   'creek',
#   'junior',
#   'oil',
#   'merchant',
#   'feder',
#   'govern',
#   'nigeria',
#   'die',
#   'along',
#   'entir',
#   'famili',
#   'wifeand',
#   'two',
#   'children',
#   'kenya',
#   'airbu',
#   'flight',
#   'sinc',
#   'heard',
#   'death',
#   'expect',
#   'next',
#   'kin',
#   'tocom',
#   'put',
#   'claim',
#   'money',
#   'heir',
#   'cannotreleas',
#   'fund',
#   'account',
#   'unless',
#   'someon',
#   'appli',
#   'claim',
#   'asth',
#   'next',
#   'kin',
#   'deceas',
#   'indic',
#   'bank',
#   'guidelin',
#   'unfortun',
#   'neither',
#   'famili',
#   'member',
#   'distant',
#   'rel',
#   'hasappear',
#   'claim',
#   'said',
#   'fund',
#   'upon',
#   'discoveri',
#   'officialsin',
#   'depart',
#   'agre',
#   'make',
#   'busi',
#   'releas',
#   'totalamount',
#   'account',
#   'heir',
#   'fund',
#   'sinc',
#   'one',
#   'came',
#   'forit',
#   'discov',
#   'either',
#   'maintain',
#   'account',
#   'bank',
#   'wiseth',
#   'fund',
#   'return',
#   'bank',
#   'treasuri',
#   'unclaim',
#   'fund',
#   'agre',
#   'ratio',
#   'share',
#   'state',
#   'thu',
#   'foreign',
#   'partner',
#   'us',
#   'offici',
#   'depart',
#   'upon',
#   'success',
#   'complet',
#   'transfer',
#   'colleagu',
#   'willcom',
#   'countri',
#   'mind',
#   'share',
#   'intendto',
#   'import',
#   'comput',
#   'accessori',
#   'countri',
#   'way',
#   'recycl',
#   'thefund',
#   'commenc',
#   'transact',
#   'requir',
#   'immedi',
#   'indicateyour',
#   'interest',
#   'call',
#   'send',
#   'fax',
#   'immedi',
#   'abovetelefax',
#   'enclos',
#   'privat',
#   'contact',
#   'telephon',
#   'fax',
#   'full',
#   'nameand',
#   'address',
#   'design',
#   'bank',
#   'ordin',
#   'enabl',
#   'us',
#   'filelett',
#   'claim',
#   'appropri',
#   'depart',
#   'necessari',
#   'approvalsbefor',
#   'transfer',
#   'made',
#   'note',
#   'also',
#   'transact',
#   'must',
#   'kept',
#   'strictli',
#   'confidenti',
#   'becauseof',
#   'natur',
#   'nb',
#   'pleas',
#   'rememb',
#   'give',
#   'phone',
#   'fax',
#   'smith',
#   'abu',
#   'irish',
#   'linux',
#   'user',
#   'group',
#   'ilug',
#   'http',
#   'un',
#   'subscript',
#   'inform',
#   'list',
#   'maintain',
#   'listmast'],
#  ['messag',
#   'mime',
#   'format',
#   'bassey',
#   'associ',
#   'falomo',
#   'ikoyi',
#   'lago',
#   'nigeria',
#   'kind',
#   'attent',
#   'request',
#   'mutual',
#   'benefit',
#   'endeavour',
#   'humbl',
#   'crave',
#   'indulg',
#   'send',
#   'mail',
#   'content',
#   'meet',
#   'person',
#   'busi',
#   'ethic',
#   'apolog',
#   'advanc',
#   'barrist',
#   'william',
#   'bassey',
#   'attorney',
#   'law',
#   'repres',
#   'alhaji',
#   'ishmaila',
#   'ibrahim',
#   'gwarzo',
#   'estat',
#   'alhaji',
#   'gwarzo',
#   'chief',
#   'secur',
#   'advic',
#   'militari',
#   'leader',
#   'countri',
#   'nigeria',
#   'person',
#   'late',
#   'gener',
#   'sani',
#   'abacha',
#   'die',
#   'june',
#   'advent',
#   'new',
#   'democrat',
#   'dispens',
#   'countri',
#   'leadership',
#   'olusegun',
#   'obasanjo',
#   'rtd',
#   'client',
#   'come',
#   'sever',
#   'persecut',
#   'due',
#   'sensit',
#   'posit',
#   'held',
#   'last',
#   'militari',
#   'regim',
#   'present',
#   'hous',
#   'arrest',
#   'restrict',
#   'confin',
#   'villag',
#   'main',
#   'purpos',
#   'mail',
#   'intim',
#   'busi',
#   'propos',
#   'might',
#   'interest',
#   'client',
#   'inform',
#   'exist',
#   'fund',
#   'deposit',
#   'secur',
#   'compani',
#   'abroad',
#   'fund',
#   'came',
#   'part',
#   'secur',
#   'vote',
#   'alloc',
#   'portfolio',
#   'tenur',
#   'chief',
#   'secur',
#   'advic',
#   'presid',
#   'happen',
#   'part',
#   'fund',
#   'transfer',
#   'vault',
#   'central',
#   'bank',
#   'nigeria',
#   'secur',
#   'outfit',
#   'aim',
#   'purchas',
#   'arm',
#   'ammunit',
#   'person',
#   'secur',
#   'outfit',
#   'presid',
#   'purchas',
#   'could',
#   'take',
#   'place',
#   'presid',
#   'die',
#   'client',
#   'deceid',
#   'keep',
#   'properti',
#   'confist',
#   'present',
#   'regim',
#   'due',
#   'incarcer',
#   'travel',
#   'effect',
#   'chang',
#   'possess',
#   'benefit',
#   'mandat',
#   'client',
#   'sourc',
#   'foreign',
#   'partner',
#   'help',
#   'facilit',
#   'chang',
#   'possess',
#   'deposit',
#   'certif',
#   'code',
#   'need',
#   'execut',
#   'endeavour',
#   'possess',
#   'fund',
#   'question',
#   'million',
#   'six',
#   'hundr',
#   'thousand',
#   'unit',
#   'state',
#   'dollar',
#   'proposit',
#   'interest',
#   'reach',
#   'address',
#   'go',
#   'rudiment',
#   'endeavour',
#   'remain',
#   'oblig',
#   'barrist',
#   'william',
#   'bassey',
#   'jp',
#   'princip',
#   'bassey',
#   'associ',
#   'bassey',
#   'associ',
#   'falomo',
#   'ikoyi',
#   'lago',
#   'nigeria',
#   'kind',
#   'attent',
#   'request',
#   'mutual',
#   'benefit',
#   'endeavour',
#   'humbl',
#   'crave',
#   'indulg',
#   'send',
#   'mail',
#   'content',
#   'meet',
#   'person',
#   'busi',
#   'ethic',
#   'apolog',
#   'advanc',
#   'barrist',
#   'william',
#   'bassey',
#   'attorney',
#   'law',
#   'repres',
#   'alhaji',
#   'ishmaila',
#   'ibrahim',
#   'gwarzo',
#   'estat',
#   'alhaji',
#   'gwarzo',
#   'chief',
#   'secur',
#   'advic',
#   'militari',
#   'leader',
#   'countri',
#   'nigeria',
#   'person',
#   'late',
#   'gener',
#   'sani',
#   'abacha',
#   'die',
#   'june',
#   'advent',
#   'new',
#   'democrat',
#   'dispens',
#   'countri',
#   'leadership',
#   'olusegun',
#   'obasanjo',
#   'rtd',
#   'client',
#   'come',
#   'sever',
#   'persecut',
#   'due',
#   'sensit',
#   'posit',
#   'held',
#   'last',
#   'militari',
#   'regim',
#   'present',
#   'hous',
#   'arrest',
#   'restrict',
#   'confin',
#   'villag',
#   'main',
#   'purpos',
#   'mail',
#   'intim',
#   'busi',
#   'propos',
#   'might',
#   'interest',
#   'client',
#   'inform',
#   'exist',
#   'fund',
#   'deposit',
#   'secur',
#   'compani',
#   'abroad',
#   'fund',
#   'came',
#   'part',
#   'secur',
#   'vote',
#   'alloc',
#   'client',
#   'portfolio',
#   'tenur',
#   'chief',
#   'secur',
#   'advic',
#   'presid',
#   'happen',
#   'part',
#   'fund',
#   'transfer',
#   'vault',
#   'central',
#   'bank',
#   'nigeria',
#   'secur',
#   'outfit',
#   'aim',
#   'purchas',
#   'arm',
#   'ammunit',
#   'person',
#   'secur',
#   'outfit',
#   'presid',
#   'purchas',
#   'could',
#   'take',
#   'place',
#   'presid',
#   'die',
#   'client',
#   'deceid',
#   'keep',
#   'properti',
#   'confist',
#   'present',
#   'regim',
#   'due',
#   'incarcer',
#   'travel',
#   'effect',
#   'chang',
#   'possess',
#   'benefit',
#   'mandat',
#   'client',
#   'sourc',
#   'foreign',
#   'partner',
#   'help',
#   'facilit',
#   'chang',
#   'possess',
#   'deposit',
#   'certif',
#   'code',
#   'need',
#   'execut',
#   'endeavour',
#   'possess',
#   'fund',
#   'question',
#   'million',
#   'six',
#   'hundr',
#   'thousand',
#   'unit',
#   'state',
#   'dollar',
#   'proposit',
#   'interest',
#   'reach',
#   'address',
#   'go',
#   'rudiment',
#   'endeavour',
#   'remain',
#   'oblig',
#   'barrist',
#   'william',
#   'bassey',
#   'jp',
#   'princip',
#   'bassey',
#   'associ'],
#  ['hallo',
#   'found',
#   'email',
#   'id',
#   'director',
#   'russian',
#   'man',
#   'like',
#   'lookink',
#   'http',
#   'want',
#   'hear',
#   'repli',
#   'bother'],
#  ['lowest',
#   'rate',
#   'avail',
#   'term',
#   'life',
#   'insur',
#   'take',
#   'moment',
#   'fill',
#   'onlin',
#   'form',
#   'see',
#   'low',
#   'rate',
#   'qualifi',
#   'save',
#   'regular',
#   'rate',
#   'smoker',
#   'accept',
#   'http',
#   'repres',
#   'qualiti',
#   'nationwid',
#   'carrier',
#   'act',
#   'easili',
#   'remov',
#   'address',
#   'list',
#   'go',
#   'http',
#   'pleas',
#   'allow',
#   'hour',
#   'remov'],
#  ['afford',
#   'domain',
#   'registr',
#   'everyon',
#   'new',
#   'domain',
#   'name',
#   'final',
#   'avail',
#   'gener',
#   'public',
#   'discount',
#   'price',
#   'regist',
#   'one',
#   'excit',
#   'new',
#   'domain',
#   'name',
#   'well',
#   'origin',
#   'name',
#   'brand',
#   'new',
#   'domain',
#   'extens',
#   'recent',
#   'approv',
#   'icann',
#   'right',
#   'origin',
#   'domain',
#   'name',
#   'biggest',
#   'benefit',
#   'domain',
#   'name',
#   'current',
#   'avail',
#   'much',
#   'easier',
#   'regist',
#   'attract',
#   'domain',
#   'name',
#   'price',
#   'visit',
#   'http',
#   'today',
#   'info',
#   'regist',
#   'domain',
#   'name',
#   'today',
#   'http',
#   'registr',
#   'fee',
#   'includ',
#   'full',
#   'access',
#   'control',
#   'panel',
#   'manag',
#   'domain',
#   'name',
#   'futur',
#   'sincer',
#   'domain',
#   'administr',
#   'domain',
#   'everyon',
#   'remov',
#   'email',
#   'address',
#   'promot',
#   'mail',
#   'compani',
#   'click',
#   'http'],
#  ['strongli',
#   'send',
#   'unsolicit',
#   'email',
#   'wish',
#   'receiv',
#   'special',
#   'opt',
#   'one',
#   'affili',
#   'site',
#   'request',
#   'notifi',
#   'special',
#   'offer',
#   'may',
#   'run',
#   'time',
#   'time',
#   'wish',
#   'receiv',
#   'mail',
#   'pleas',
#   'click',
#   'link',
#   'pleas',
#   'accept',
#   'apolog',
#   'sent',
#   'email',
#   'error',
#   'honor',
#   'remov',
#   'request'],
#  ['messag',
#   'mime',
#   'format',
#   'way',
#   'slice',
#   'ge',
#   'lifetim',
#   'protector',
#   'cut',
#   'underwritten',
#   'gener',
#   'electr',
#   'capit',
#   'assur',
#   'compani',
#   'first',
#   'coloni',
#   'life',
#   'insur',
#   'compani',
#   'ge',
#   'lifetim',
#   'protector',
#   'univers',
#   'life',
#   'insur',
#   'cook',
#   'competit',
#   'competit',
#   'premium',
#   'male',
#   'age',
#   'best',
#   'face',
#   'amount',
#   'annual',
#   'premium',
#   'ge',
#   'lifetim',
#   'protectorsm',
#   'lifetim',
#   'age',
#   'amt',
#   'age',
#   'product',
#   'j',
#   'product',
#   'product',
#   'l',
#   'product',
#   'product',
#   'u',
#   'product',
#   'product',
#   'product',
#   'g',
#   'sourc',
#   'industri',
#   'market',
#   'research',
#   'conduct',
#   'compil',
#   'ge',
#   'financi',
#   'august',
#   'ge',
#   'lifetim',
#   'protectorsm',
#   'subject',
#   'term',
#   'issu',
#   'limit',
#   'condit',
#   'polici',
#   'form',
#   'no',
#   'ul',
#   'et',
#   'al',
#   'ge',
#   'capit',
#   'assur',
#   'et',
#   'al',
#   'first',
#   'coloni',
#   'life',
#   'includ',
#   'exclus',
#   'period',
#   'death',
#   'suicid',
#   'ge',
#   'lifetim',
#   'protectorsm',
#   'avail',
#   'state',
#   'guarante',
#   'coverag',
#   'life',
#   'insur',
#   'accord',
#   'compani',
#   'provis',
#   'compani',
#   'refer',
#   'premium',
#   'differ',
#   'name',
#   'condit',
#   'guarante',
#   'vari',
#   'compani',
#   'compani',
#   'ge',
#   'lifetim',
#   'protectorsm',
#   'refer',
#   'design',
#   'premium',
#   'requir',
#   'subject',
#   'polici',
#   'provis',
#   'polici',
#   'remain',
#   'forc',
#   'long',
#   'sum',
#   'premium',
#   'paid',
#   'less',
#   'reduct',
#   'polici',
#   'valu',
#   'partial',
#   'withdraw',
#   'equal',
#   'exce',
#   'cumul',
#   'total',
#   'design',
#   'monthli',
#   'premium',
#   'polici',
#   'date',
#   'end',
#   'current',
#   'polici',
#   'month',
#   'calcul',
#   'assum',
#   'compani',
#   'current',
#   'credit',
#   'rate',
#   'charg',
#   'column',
#   'repres',
#   'premium',
#   'requir',
#   'annual',
#   'age',
#   'achiev',
#   'target',
#   'cash',
#   'surrend',
#   'valu',
#   'state',
#   'column',
#   'head',
#   'underwritten',
#   'gener',
#   'electr',
#   'capit',
#   'assur',
#   'compani',
#   'first',
#   'coloni',
#   'life',
#   'insur',
#   'compani',
#   'lynchburg',
#   'va',
#   'member',
#   'ge',
#   'financi',
#   'famili',
#   'compani',
#   'click',
#   'ge',
#   'lifetim',
#   'protector',
#   'sm',
#   'inform',
#   'quot',
#   'bramco',
#   'agenc',
#   'want',
#   'anyon',
#   'receiv',
#   'mail',
#   'wish',
#   'receiv',
#   'profession',
#   'commun',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal',
#   'notic',
#   'best',
#   'got',
#   'better',
#   'male',
#   'age',
#   'best',
#   'face',
#   'amount',
#   'annual',
#   'premium',
#   'ge',
#   'lifetim',
#   'protectorsm',
#   'lifetim',
#   'age',
#   'amt',
#   'age',
#   'product',
#   'j',
#   'product',
#   'product',
#   'l',
#   'product',
#   'product',
#   'u',
#   'product',
#   'product',
#   'product',
#   'g',
#   'sourc',
#   'industri',
#   'market',
#   'research',
#   'conduct',
#   'compil',
#   'ge',
#   'financi',
#   'august',
#   'ge',
#   'lifetim',
#   'subject',
#   'term',
#   'issu',
#   'limit',
#   'condit',
#   'form',
#   'no',
#   'ul',
#   'et',
#   'al',
#   'ge',
#   'capit',
#   'assur',
#   'et',
#   'first',
#   'coloni',
#   'life',
#   'includ',
#   'exclus',
#   'period',
#   'death',
#   'suicid',
#   'ge',
#   'lifetim',
#   'protectorsm',
#   'avail',
#   'state',
#   'guarante',
#   'coverag',
#   'life',
#   'insur',
#   'accord',
#   'compani',
#   'provis',
#   'compani',
#   'refer',
#   'premium',
#   'differ',
#   'name',
#   'guarante',
#   'vari',
#   'compani',
#   'compani',
#   'ge',
#   'protectorsm',
#   'refer',
#   'design',
#   'premium',
#   'requir',
#   'subject',
#   'polici',
#   'provis',
#   'polici',
#   'remain',
#   'forc',
#   'sum',
#   'premium',
#   'paid',
#   'less',
#   'reduct',
#   'polici',
#   'partial',
#   'withdraw',
#   'equal',
#   'exce',
#   'cumul',
#   'design',
#   'monthli',
#   'premium',
#   'polici',
#   'date',
#   'current',
#   'polici',
#   'month',
#   'assum',
#   'compani',
#   'current',
#   'credit',
#   'rate',
#   'charg',
#   'column',
#   'repres',
#   'premium',
#   'requir',
#   'annual',
#   'age',
#   'target',
#   'cash',
#   'surrend',
#   'valu',
#   'state',
#   'column',
#   'head',
#   'underwritten',
#   'gener',
#   'electr',
#   'capit',
#   'assur',
#   'compani',
#   'first',
#   'coloni',
#   'life',
#   'insur',
#   'compani',
#   'lynchburg',
#   'va',
#   'member',
#   'ge',
#   'financi',
#   'famili',
#   'compani',
#   'want',
#   'anyon',
#   'receiv',
#   'mail',
#   'wish',
#   'receiv',
#   'profession',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal',
#   'notic'],
#  ['dear',
#   'name',
#   'petr',
#   'stanek',
#   'manag',
#   'iraq',
#   'today',
#   'news',
#   'servic',
#   'iraq',
#   'today',
#   'contain',
#   'hourli',
#   'updat',
#   'break',
#   'news',
#   'headlin',
#   'exchang',
#   'rate',
#   'market',
#   'news',
#   'import',
#   'inform',
#   'associ',
#   'free',
#   'trial',
#   'subscript',
#   'iraq',
#   'today',
#   'access',
#   'collect',
#   'daili',
#   'updat',
#   'articl',
#   'news',
#   'archiv',
#   'mani',
#   'benefit',
#   'trial',
#   'free',
#   'subscrib',
#   'repli',
#   'sign',
#   'http',
#   'partial',
#   'list',
#   'current',
#   'ein',
#   'subscrib',
#   'found',
#   'http',
#   'question',
#   'comment',
#   'need',
#   'assist',
#   'sign',
#   'pleas',
#   'contact',
#   'us',
#   'person',
#   'either',
#   'write',
#   'helpdesk',
#   'simpli',
#   'repli',
#   'email',
#   'pleas',
#   'feel',
#   'free',
#   'forward',
#   'offer',
#   'colleagu',
#   'best',
#   'regard',
#   'petr',
#   'stanek',
#   'subscript',
#   'depart',
#   'ein',
#   'news',
#   'remov',
#   'pleas',
#   'repli',
#   'remov'],
#  ['messag',
#   'mime',
#   'format',
#   'rush',
#   'hour',
#   'traffic',
#   'safeti',
#   'fix',
#   'index',
#   'annuiti',
#   'bought',
#   'record',
#   'number',
#   'saver',
#   'investor',
#   'seek',
#   'strong',
#   'guarante',
#   'greater',
#   'upsid',
#   'earn',
#   'potenti',
#   'financi',
#   'strong',
#   'compani',
#   'octob',
#   'biggest',
#   'month',
#   'cd',
#   'rollov',
#   'cd',
#   'roll',
#   'one',
#   'reason',
#   'habit',
#   'give',
#   'client',
#   'better',
#   'altern',
#   'take',
#   'advantag',
#   'window',
#   'opportun',
#   'respond',
#   'today',
#   'receiv',
#   'free',
#   'cd',
#   'replac',
#   'kit',
#   'call',
#   'applic',
#   'bonu',
#   'free',
#   'digit',
#   'camera',
#   'captur',
#   'preciou',
#   'memori',
#   'pleas',
#   'fill',
#   'form',
#   'receiv',
#   'free',
#   'replac',
#   'cd',
#   'kit',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'want',
#   'anybodi',
#   'receiv',
#   'mail',
#   'wish',
#   'receiv',
#   'profession',
#   'commun',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal',
#   'notic',
#   'flight',
#   'safeti',
#   'upon',
#   'us',
#   'fix',
#   'annuiti',
#   'bought',
#   'record',
#   'number',
#   'saver',
#   'investor',
#   'seek',
#   'strong',
#   'guarante',
#   'greater',
#   'upsid',
#   'earn',
#   'financi',
#   'strong',
#   'compani',
#   'octob',
#   'biggest',
#   'cd',
#   'rollov',
#   'cd',
#   'roll',
#   'one',
#   'reason',
#   'habit',
#   'give',
#   'client',
#   'better',
#   'altern',
#   'take',
#   'advantag',
#   'window',
#   'opportun',
#   'applic',
#   'bonu',
#   'free',
#   'digit',
#   'camera',
#   'captur',
#   'preciou',
#   'memori',
#   'pleas',
#   'fill',
#   'form',
#   'receiv',
#   'free',
#   'replac',
#   'cd',
#   'kit',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'want',
#   'anybodi',
#   'receiv',
#   'mail',
#   'wish',
#   'receiv',
#   'profession',
#   'commun',
#   'sent',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'tout',
#   'legal'],
#  ['social',
#   'januari',
#   'european',
#   'countri',
#   'began',
#   'use',
#   'new',
#   'euro',
#   'never',
#   'mani',
#   'countri',
#   'power',
#   'economi',
#   'unit',
#   'use',
#   'singl',
#   'currenc',
#   'get',
#   'piec',
#   'histori',
#   'would',
#   'like',
#   'send',
#   'free',
#   'euro',
#   'free',
#   'report',
#   'world',
#   'currenc',
#   'visit',
#   'site',
#   'request',
#   'euro',
#   'euro',
#   'report',
#   'http',
#   'addit',
#   'currenc',
#   'report',
#   'receiv',
#   'free',
#   'invest',
#   'packag',
#   'learn',
#   'option',
#   'leverag',
#   'euro',
#   'currenc',
#   'mean',
#   'even',
#   'small',
#   'movement',
#   'market',
#   'huge',
#   'profit',
#   'potenti',
#   'csice',
#   'age',
#   'risk',
#   'capit',
#   'import',
#   'find',
#   'euro',
#   'chang',
#   'econom',
#   'world',
#   'profit',
#   'http',
#   'pleas',
#   'care',
#   'evalu',
#   'financi',
#   'posit',
#   'trade',
#   'risk',
#   'capit',
#   'use',
#   'utbxcuhepuffbnkwq',
#   'full',
#   'instruct',
#   'bottom',
#   'site',
#   'irish',
#   'linux',
#   'user',
#   'group',
#   'social',
#   'event',
#   'social',
#   'http',
#   'un',
#   'subscript',
#   'inform',
#   'list',
#   'maintain',
#   'listmast'],
#  ['man',
#   'endow',
#   'hammer',
#   'simpli',
#   'better',
#   'equip',
#   'man',
#   'hammer',
#   'would',
#   'rather',
#   'havemor',
#   'enough',
#   'get',
#   'job',
#   'done',
#   'fall',
#   'short',
#   'total',
#   'upto',
#   'method',
#   'guarante',
#   'ase',
#   'size',
#   'enter',
#   'see'],
#  ['would',
#   'like',
#   'know',
#   'powerbal',
#   'win',
#   'lotteri',
#   'number',
#   'morn',
#   'follow',
#   'link',
#   'mailto',
#   'although',
#   'everi',
#   'attempt',
#   'made',
#   'ensur',
#   'list',
#   'number',
#   'accur',
#   'offici',
#   'win',
#   'number',
#   'record',
#   'offici',
#   'draw',
#   'file',
#   'certifi',
#   'independ',
#   'account',
#   'firm',
#   'request',
#   'player',
#   'number',
#   'list',
#   'numer',
#   'order',
#   'wednesday',
#   'septemb',
#   'draw',
#   'result',
#   'pb',
#   'pp',
#   'visit',
#   'http',
#   'tire',
#   'job',
#   'pleas',
#   'visit',
#   'http',
#   'time',
#   'retir'],
#  [],
#  ['click',
#   'simpli',
#   'amateur',
#   'like',
#   'girl',
#   'next',
#   'door',
#   'xxx',
#   'free',
#   'tour',
#   'first',
#   'time',
#   'photo',
#   'sneeki',
#   'hidden',
#   'cam',
#   'nude',
#   'exibitionist',
#   'cheat',
#   'wive',
#   'girlfriend',
#   'click',
#   'remov'],
#  ['meridian',
#   'east',
#   'leicest',
#   'leicest',
#   'citi',
#   'unit',
#   'kingdom',
#   'date',
#   'capt',
#   'john',
#   'okel',
#   'dear',
#   'sir',
#   'got',
#   'contact',
#   'militari',
#   'friend',
#   'train',
#   'countri',
#   'captain',
#   'john',
#   'okel',
#   'former',
#   'command',
#   'secur',
#   'guard',
#   'late',
#   'laurent',
#   'kabila',
#   'former',
#   'presid',
#   'democrat',
#   'republ',
#   'congo',
#   'africa',
#   'present',
#   'wife',
#   'one',
#   'child',
#   'remot',
#   'leicest',
#   'citi',
#   'britain',
#   'due',
#   'threat',
#   'present',
#   'govern',
#   'head',
#   'son',
#   'late',
#   'laurent',
#   'kabila',
#   'life',
#   'famili',
#   'kill',
#   'say',
#   'know',
#   'death',
#   'father',
#   'assist',
#   'late',
#   'presid',
#   'laurent',
#   'kabila',
#   'keep',
#   'us',
#   'thirti',
#   'five',
#   'million',
#   'secur',
#   'compani',
#   'war',
#   'countri',
#   'although',
#   'secur',
#   'compani',
#   'know',
#   'content',
#   'box',
#   'deposit',
#   'deposit',
#   'person',
#   'effect',
#   'laurent',
#   'kabila',
#   'respect',
#   'seek',
#   'help',
#   'assist',
#   'invest',
#   'fund',
#   'present',
#   'govern',
#   'head',
#   'son',
#   'knowledg',
#   'money',
#   'avoid',
#   'take',
#   'away',
#   'conclus',
#   'busi',
#   'shall',
#   'compens',
#   'fund',
#   'map',
#   'expens',
#   'encount',
#   'caus',
#   'transact',
#   'remain',
#   'amount',
#   'use',
#   'open',
#   'account',
#   'famili',
#   'invest',
#   'assist',
#   'need',
#   'profit',
#   'invest',
#   'plan',
#   'compani',
#   'term',
#   'suggest',
#   'idea',
#   'requir',
#   'urgent',
#   'expect',
#   'prompt',
#   'respons',
#   'also',
#   'furnish',
#   'current',
#   'address',
#   'number',
#   'privat',
#   'person',
#   'contact',
#   'note',
#   'pleas',
#   'call',
#   'fax',
#   'line',
#   'belong',
#   'cousin',
#   'know',
#   'confidenti',
#   'reach',
#   'direct',
#   'mail',
#   'faith',
#   'capt',
#   'john',
#   'okel',
#   'privat',
#   'johnokel'],
#  ['protect',
#   'financi',
#   'purchas',
#   'extend',
#   'auto',
#   'warranti',
#   'car',
#   'today',
#   'click',
#   'free',
#   'oblig',
#   'quot',
#   'http',
#   'car',
#   'troubl',
#   'alway',
#   'seem',
#   'happen',
#   'worst',
#   'possibl',
#   'time',
#   'protect',
#   'famili',
#   'qualiti',
#   'extend',
#   'warranti',
#   'car',
#   'truck',
#   'suv',
#   'larg',
#   'expens',
#   'hit',
#   'cover',
#   'vehicl',
#   'less',
#   'mile',
#   'buy',
#   'direct',
#   'price',
#   'less',
#   'offer',
#   'fair',
#   'price',
#   'prompt',
#   'claim',
#   'servic',
#   'get',
#   'extend',
#   'warranti',
#   'quot',
#   'car',
#   'today',
#   'warranti',
#   'plan',
#   'also',
#   'includ',
#   'roadsid',
#   'assist',
#   'rental',
#   'benefit',
#   'trip',
#   'interrupt',
#   'intervent',
#   'extend',
#   'tow',
#   'benefit',
#   'click',
#   'free',
#   'oblig',
#   'quot',
#   'http',
#   'easili',
#   'remov',
#   'address',
#   'list',
#   'go',
#   'http',
#   'pleas',
#   'allow',
#   'hour',
#   'remov'],
#  ['tire',
#   'pay',
#   'big',
#   'buck',
#   'satellit',
#   'dont',
#   'low',
#   'buy',
#   'program',
#   'card',
#   'give',
#   'channel',
#   'ye',
#   'includ',
#   'pay',
#   'channel',
#   'pay',
#   'per',
#   'view',
#   'never',
#   'anoth',
#   'satellit',
#   'cabl',
#   'bill',
#   'http',
#   'littl',
#   'got',
#   'work',
#   'unblock',
#   'receiv',
#   'channel',
#   'movi',
#   'channel',
#   'pron',
#   'channel',
#   'channel',
#   'unlock',
#   'includ',
#   'pay',
#   'per',
#   'view',
#   'event',
#   'free',
#   'life',
#   'http'],
#  ['comput',
#   'need',
#   'oil',
#   'chang',
#   'uter',
#   'need',
#   'oil',
#   'chang',
#   'ortonsystemwork',
#   'profession',
#   'edit',
#   'made',
#   'creator',
#   'softwar',
#   'market',
#   'unbeat',
#   'softwar',
#   'suit',
#   'come',
#   'everi',
#   'program',
#   'ever',
#   'need',
#   'answer',
#   'problem',
#   'threat',
#   'comput',
#   'face',
#   'day',
#   'life',
#   'includ',
#   'magnific',
#   'deal',
#   'follow',
#   'program',
#   'norton',
#   'protecion',
#   'ever',
#   'norton',
#   'diagnos',
#   'problem',
#   'th',
#   'system',
#   'norton',
#   'make',
#   'back',
#   'valuabl',
#   'data',
#   'easi',
#   'norton',
#   'clean',
#   'excess',
#   'internet',
#   'file',
#   'buildup',
#   'norton',
#   'basic',
#   'turn',
#   'cpu',
#   'fax',
#   'machin',
#   'person',
#   'help',
#   'prevent',
#   'make',
#   'mistak',
#   'retail',
#   'price',
#   'buy',
#   'free',
#   'ship',
#   'plu',
#   'buy',
#   'item',
#   'get',
#   'free',
#   'also',
#   'ship',
#   'click',
#   'order',
#   'product',
#   'avail',
#   'run',
#   'gone',
#   'get',
#   'hot',
#   'email',
#   'address',
#   'obtain',
#   'list',
#   'iaa',
#   'internet',
#   'advertis',
#   'associ',
#   'approv',
#   'list',
#   'serial',
#   'code',
#   'wish',
#   'unsubscrib',
#   'list',
#   'pleas',
#   'click',
#   'condon',
#   'spam',
#   'shape',
#   'form',
#   'thank',
#   'dli',
#   'cooper'],
#  ['messag',
#   'mime',
#   'format',
#   'maxim',
#   'select',
#   'want',
#   'pay',
#   'less',
#   'term',
#   'insur',
#   'find',
#   'client',
#   'pay',
#   'less',
#   'pay',
#   'earn',
#   'commiss',
#   'simplifi',
#   'underwrit',
#   'advanc',
#   'commiss',
#   'return',
#   'premium',
#   'renew',
#   'commiss',
#   'call',
#   'today',
#   'find',
#   'cna',
#   'maxim',
#   'select',
#   'work',
#   'pleas',
#   'fill',
#   'form',
#   'inform',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'cna',
#   'cna',
#   'life',
#   'regist',
#   'servic',
#   'mark',
#   'trade',
#   'name',
#   'domain',
#   'name',
#   'cna',
#   'maxim',
#   'regist',
#   'servic',
#   'mark',
#   'cna',
#   'financi',
#   'corpor',
#   'cna',
#   'life',
#   'insur',
#   'product',
#   'underwritten',
#   'valley',
#   'forg',
#   'life',
#   'insur',
#   'compani',
#   'one',
#   'cna',
#   'compani',
#   'polici',
#   'form',
#   'number',
#   'seri',
#   'product',
#   'featur',
#   'avail',
#   'state',
#   'produc',
#   'use',
#   'want',
#   'anybodi',
#   'receiv',
#   'mail',
#   'wish',
#   'receiv',
#   'profession',
#   'commun',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal',
#   'notic',
#   'sometim',
#   'less',
#   'find',
#   'client',
#   'pay',
#   'less',
#   'payingmor',
#   'earn',
#   'commiss',
#   'simplifi',
#   'underwrit',
#   'advanc',
#   'commiss',
#   'return',
#   'premium',
#   'renew',
#   'commiss',
#   'call',
#   'today',
#   'find',
#   'howcna',
#   'maxim',
#   'select',
#   'work',
#   'pleas',
#   'fill',
#   'form',
#   'inform',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'cna',
#   'life',
#   'regist',
#   'servic',
#   'mark',
#   'trade',
#   'name',
#   'name',
#   'cna',
#   'maxim',
#   'regist',
#   'servic',
#   'mark',
#   'cna',
#   'corpor',
#   'cna',
#   'life',
#   'insur',
#   'product',
#   'underwritten',
#   'forg',
#   'life',
#   'insur',
#   'compani',
#   'one',
#   'cna',
#   'compani',
#   'polici',
#   'number',
#   'product',
#   'featur',
#   'avail',
#   'state',
#   'use',
#   'want',
#   'anybodi',
#   'receiv',
#   'mail',
#   'wish',
#   'receiv',
#   'profession',
#   'commun',
#   'sent',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'tout',
#   'legal'],
#  ['messag',
#   'mime',
#   'format',
#   'welcom',
#   'jefferson',
#   'gateway',
#   'wealth',
#   'one',
#   'industri',
#   'premier',
#   'produc',
#   'must',
#   'continu',
#   'seek',
#   'qualifi',
#   'cut',
#   'edg',
#   'servic',
#   'financi',
#   'profil',
#   'concept',
#   'profession',
#   'person',
#   'busi',
#   'analysi',
#   'tool',
#   'analyz',
#   'client',
#   'insur',
#   'invest',
#   'financi',
#   'plan',
#   'goal',
#   'help',
#   'see',
#   'situat',
#   'today',
#   'compar',
#   'object',
#   'market',
#   'profession',
#   'ideal',
#   'tool',
#   'true',
#   'financi',
#   'plan',
#   'provid',
#   'thorough',
#   'analysi',
#   'includ',
#   'asset',
#   'alloc',
#   'calcul',
#   'tax',
#   'implic',
#   'client',
#   'plan',
#   'due',
#   'modular',
#   'format',
#   'use',
#   'specif',
#   'plan',
#   'need',
#   'well',
#   'comprehens',
#   'plan',
#   'benefit',
#   'softwar',
#   'provid',
#   'except',
#   'analysi',
#   'excel',
#   'provid',
#   'simpl',
#   'well',
#   'comprehens',
#   'present',
#   'page',
#   'uncov',
#   'multipl',
#   'need',
#   'produc',
#   'sell',
#   'product',
#   'concept',
#   'servic',
#   'allow',
#   'user',
#   'quickli',
#   'becom',
#   'success',
#   'defer',
#   'compens',
#   'coli',
#   'market',
#   'market',
#   'focu',
#   'busi',
#   'area',
#   'execut',
#   'benefit',
#   'opportun',
#   'defin',
#   'either',
#   'number',
#   'employe',
#   'within',
#   'compani',
#   'specif',
#   'number',
#   'highli',
#   'compens',
#   'execut',
#   'within',
#   'compani',
#   'benefit',
#   'turnkey',
#   'program',
#   'includ',
#   'qualif',
#   'prospect',
#   'market',
#   'sale',
#   'support',
#   'case',
#   'design',
#   'plan',
#   'document',
#   'administr',
#   'concept',
#   'global',
#   'insur',
#   'fund',
#   'transact',
#   'sophist',
#   'program',
#   'provid',
#   'altern',
#   'fund',
#   'mechan',
#   'life',
#   'product',
#   'purchas',
#   'offset',
#   'larg',
#   'estat',
#   'corpor',
#   'liabil',
#   'market',
#   'client',
#   'high',
#   'net',
#   'worth',
#   'least',
#   'million',
#   'insur',
#   'need',
#   'believ',
#   'exist',
#   'portfolio',
#   'invest',
#   'left',
#   'unliquid',
#   'earn',
#   'pay',
#   'loan',
#   'interest',
#   'expens',
#   'benefit',
#   'offer',
#   'compel',
#   'sale',
#   'solut',
#   'comprehens',
#   'supplement',
#   'illustr',
#   'access',
#   'consortium',
#   'establish',
#   'bank',
#   'will',
#   'abl',
#   'lend',
#   'market',
#   'loan',
#   'avail',
#   'dollar',
#   'japanes',
#   'yen',
#   'pleas',
#   'fill',
#   'form',
#   'inform',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'zip',
#   'primari',
#   'insur',
#   'carrier',
#   'current',
#   'contract',
#   'jefferson',
#   'pilot',
#   'financi',
#   'famili',
#   'compani',
#   'pleas',
#   'disregard',
#   'ad',
#   'want',
#   'anybodi',
#   'receiv',
#   'mail',
#   'wish',
#   'receiv',
#   'profession',
#   'commun',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal',
#   'notic',
#   'gateway',
#   'wealth',
#   'profession',
#   'person',
#   'busi',
#   'analysi',
#   'tool',
#   'client',
#   'insur',
#   'invest',
#   'financi',
#   'plan',
#   'goal',
#   'help',
#   'see',
#   'situat',
#   'today',
#   'compar',
#   'profession',
#   'ideal',
#   'tool',
#   'true',
#   'financi',
#   'plan',
#   'provid',
#   'thorough',
#   'analysi',
#   'includ',
#   'asset',
#   'alloc',
#   'calcul',
#   'tax',
#   'implic',
#   'client',
#   'plan',
#   'due',
#   'modular',
#   'format',
#   'use',
#   'specif',
#   'plan',
#   'need',
#   'comprehens',
#   'plan',
#   'softwar',
#   'provid',
#   'except',
#   'analysi',
#   'excel',
#   'simpl',
#   'well',
#   'comprehens',
#   'present',
#   'page',
#   'multipl',
#   'need',
#   'produc',
#   'sell',
#   'product',
#   'servic',
#   'user',
#   'quickli',
#   'becom',
#   'success',
#   'defer',
#   'coli',
#   'market',
#   'focu',
#   'busi',
#   'area',
#   'execut',
#   'benefit',
#   'opportun',
#   'defin',
#   'either',
#   'employe',
#   'within',
#   'compani',
#   'specif',
#   'highli',
#   'compens',
#   'execut',
#   'within',
#   'compani',
#   'turnkey',
#   'program',
#   'includ',
#   'qualif',
#   'prospect',
#   'sale',
#   'support',
#   'case',
#   'design',
#   'plan',
#   'document',
#   'insur',
#   'fund',
#   'transact',
#   'sophist',
#   'program',
#   'provid',
#   'altern',
#   'fund',
#   'mechan',
#   'product',
#   'purchas',
#   'offset',
#   'larg',
#   'estat',
#   'corpor',
#   'client',
#   'high',
#   'net',
#   'worth',
#   'least',
#   'million',
#   'insur',
#   'need',
#   'believ',
#   'exist',
#   'portfolio',
#   'invest',
#   'left',
#   'unliquid',
#   'earn',
#   'loan',
#   'interest',
#   'expens',
#   'offer',
#   'compel',
#   'sale',
#   'solut',
#   'comprehens',
#   'illustr',
#   'access',
#   'consortium',
#   'establish',
#   'bank',
#   'abl',
#   'lend',
#   'market',
#   'loan',
#   'avail',
#   'dollar',
#   'japanes',
#   'yen',
#   'pleas',
#   'fill',
#   'form',
#   'inform',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'zip',
#   'primari',
#   'insur',
#   'carrier',
#   'current',
#   'contract',
#   'jefferson',
#   'pilot',
#   'financi',
#   'famili',
#   'compani',
#   'pleas',
#   'disregard',
#   'ad',
#   'want',
#   'anybodi',
#   'receiv',
#   'mail',
#   'receiv',
#   'profession',
#   'commun',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal',
#   'notic'],
#  ['import',
#   'inform',
#   'new',
#   'domain',
#   'name',
#   'final',
#   'avail',
#   'gener',
#   'public',
#   'discount',
#   'price',
#   'regist',
#   'one',
#   'excit',
#   'new',
#   'domain',
#   'name',
#   'well',
#   'origin',
#   'name',
#   'brand',
#   'new',
#   'domain',
#   'extens',
#   'recent',
#   'approv',
#   'icann',
#   'right',
#   'origin',
#   'domain',
#   'name',
#   'biggest',
#   'benefit',
#   'domain',
#   'name',
#   'current',
#   'avail',
#   'much',
#   'easier',
#   'regist',
#   'attract',
#   'domain',
#   'name',
#   'price',
#   'visit',
#   'http',
#   'today',
#   'info',
#   'regist',
#   'domain',
#   'name',
#   'today',
#   'http',
#   'registr',
#   'fee',
#   'includ',
#   'full',
#   'access',
#   'control',
#   'panel',
#   'manag',
#   'domain',
#   'name',
#   'futur',
#   'sincer',
#   'domain',
#   'administr',
#   'afford',
#   'domain',
#   'remov',
#   'email',
#   'address',
#   'promot',
#   'mail',
#   'compani',
#   'click',
#   'http'],
#  ['click', 'see', 'bang', 'busit', 'wild', 'tepyycemkckiflbsvpcyi'],
#  ['messag',
#   'mime',
#   'format',
#   'term',
#   'insur',
#   'perman',
#   'insur',
#   'diversifi',
#   'make',
#   'better',
#   'better',
#   'product',
#   'better',
#   'commiss',
#   'better',
#   'case',
#   'design',
#   'better',
#   'servic',
#   'better',
#   'market',
#   'concept',
#   'aggress',
#   'underwrit',
#   'program',
#   'tabl',
#   'standard',
#   'perman',
#   'case',
#   'compani',
#   'term',
#   'perman',
#   'life',
#   'insur',
#   'underwrit',
#   'simplifi',
#   'guarante',
#   'issu',
#   'program',
#   'case',
#   'low',
#   'cost',
#   'lifetim',
#   'guarante',
#   'underwrit',
#   'event',
#   'diversifi',
#   'brokerag',
#   'specialist',
#   'combin',
#   'best',
#   'technolog',
#   'person',
#   'servic',
#   'sinc',
#   'make',
#   'sure',
#   'ask',
#   'full',
#   'line',
#   'disabl',
#   'ltc',
#   'product',
#   'ca',
#   'ca',
#   'done',
#   'call',
#   'diversifi',
#   'brokerag',
#   'specialist',
#   'today',
#   'pleas',
#   'fill',
#   'form',
#   'inform',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'diversifi',
#   'brokerag',
#   'specialist',
#   'better',
#   'servic',
#   'technolog',
#   'visit',
#   'us',
#   'onlin',
#   'want',
#   'anyon',
#   'receiv',
#   'mail',
#   'wish',
#   'profession',
#   'commun',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal',
#   'notic',
#   'term',
#   'insur',
#   'aggress',
#   'underwrit',
#   'program',
#   'tabl',
#   'standard',
#   'perman',
#   'case',
#   'compani',
#   'term',
#   'perman',
#   'life',
#   'insur',
#   'underwrit',
#   'simplifi',
#   'guarante',
#   'issu',
#   'program',
#   'case',
#   'low',
#   'cost',
#   'lifetim',
#   'guarante',
#   'underwrit',
#   'event',
#   'diversifi',
#   'brokerag',
#   'specialist',
#   'combin',
#   'best',
#   'technolog',
#   'person',
#   'servic',
#   'sinc',
#   'make',
#   'sure',
#   'ask',
#   'full',
#   'line',
#   'disabl',
#   'ltc',
#   'product',
#   'ca',
#   'ca',
#   'done',
#   'call',
#   'diversifi',
#   'brokerag',
#   'specialist',
#   'today',
#   'pleas',
#   'fill',
#   'form',
#   'inform',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'visit',
#   'us',
#   'onlin',
#   'want',
#   'receiv',
#   'mail',
#   'wish',
#   'profession',
#   'sent',
#   'insur',
#   'profession',
#   'remov',
#   'mail',
#   'list',
#   'repli',
#   'messag',
#   'instead',
#   'go',
#   'http',
#   'legal'],
#  ['messag',
#   'mime',
#   'format',
#   'homeown',
#   'ca',
#   'wrong',
#   'agent',
#   'opportun',
#   'avail',
#   'mortgag',
#   'save',
#   'program',
#   'tm',
#   'great',
#   'new',
#   'product',
#   'client',
#   'year',
#   'old',
#   'compani',
#   'leader',
#   'industri',
#   'refinanc',
#   'fee',
#   'payrol',
#   'deduct',
#   'credit',
#   'report',
#   'paperwork',
#   'group',
#   'requir',
#   'gener',
#   'free',
#   'lead',
#   'perpetu',
#   'commiss',
#   'competit',
#   'current',
#   'mortgag',
#   'dollar',
#   'amount',
#   'mortgag',
#   'percentag',
#   'rate',
#   'mortgag',
#   'current',
#   'monthli',
#   'payment',
#   'total',
#   'interest',
#   'paid',
#   'paid',
#   'year',
#   'plan',
#   'payment',
#   'total',
#   'interest',
#   'paid',
#   'total',
#   'interest',
#   'save',
#   'paid',
#   'year',
#   'number',
#   'payment',
#   'save',
#   'equival',
#   'interest',
#   'rate',
#   'call',
#   'today',
#   'inform',
#   'ext',
#   'pleas',
#   'fill',
#   'form',
#   'inform',
#   'name',
#   'phone',
#   'citi',
#   'state',
#   'timezon',
#   'eastern',
#   'central',
#   'mountain',
#   'pacif',
#   'want',
#   'anyon',
#   'receiv',
#   'mail',
#   'wish',
#   'profession',
#   'commun',
#   'sent',
#   'insur',
# ...
#   'email',
#   'broadcast',
#   'spam',
#   'therefor',
#   'design',
#   'system',
#   'clean',
#   'databas',
#   'individu',
#   'wish',
#   'receiv',
#   'announc',
#   'type',
#   'offer',
#   'save',
#   'opportun',
#   'buy',
#   'product',
#   'substanti',
#   'reduc',
#   'price',
#   'pleas',
#   'remov',
#   'email',
#   'address',
#   'wish',
#   'receiv',
#   'commun',
#   'hope',
#   'keep',
#   'line',
#   'commun',
#   'open',
#   'first',
#   'introduct',
#   'shopper',
#   'paradis',
#   'within',
#   'hour',
#   'messag',
#   'hope',
#   'take',
#   'opportun',
#   'review',
#   'action',
#   'requir',
#   'wish',
#   'remain',
#   'commun',
#   'list',
#   'automat',
#   'unsubscrib',
#   'appreci',
#   'assist',
#   'hope',
#   'appreci',
#   'effort',
#   'clean',
#   'databas',
#   'spam',
#   'free',
#   'thank',
#   'decis',
#   'accept',
#   'messag',
#   'unsubscrib',
#   'whichev',
#   'choic',
#   'still',
#   'us',
#   'commit',
#   'send',
#   'valuabl',
#   'inform',
#   'substanti',
#   'save',
#   'shop',
#   'onlin',
#   'pat'],
#  ['ilk',
#   'kez',
#   'uygulanan',
#   'bir',
#   'sistemi',
#   'hayata',
#   'http',
#   'bu',
#   'sisteml',
#   'leri',
#   'ister',
#   'tek',
#   'tek',
#   'isterseniz',
#   'halind',
#   'dakika',
#   'sanki',
#   'disketten',
#   'gibi',
#   'indirebilirsiniz',
#   'turk',
#   'mler',
#   'klipler',
#   'daha',
#   'lik',
#   'atmak',
#   'http',
#   'com',
#   'deathtospamdeathtospamdeathtospam',
#   'email',
#   'sponsor',
#   'jabber',
#   'world',
#   'fastest',
#   'grow',
#   'commun',
#   'platform',
#   'im',
#   'build',
#   'http',
#   'mail',
#   'list',
#   'http'],
#  ['messag',
#   'transfer',
#   'trial',
#   'version',
#   'communig',
#   'tm',
#   'free',
#   'debt',
#   'consolid',
#   'inform',
#   'free',
#   'minut',
#   'debt',
#   'consolid',
#   'quot',
#   'quickli',
#   'easili',
#   'reduc',
#   'monthli',
#   'debt',
#   'payment',
#   'organ',
#   'help',
#   'consolid',
#   'debt',
#   'one',
#   'easi',
#   'afford',
#   'monthli',
#   'payment',
#   'free',
#   'oblig',
#   'quot',
#   'see',
#   'much',
#   'money',
#   'save',
#   'pleas',
#   'read',
#   'debt',
#   'free',
#   'get',
#   'life',
#   'back',
#   'track',
#   'credit',
#   'accept',
#   'home',
#   'ownership',
#   'requir',
#   'anoth',
#   'loan',
#   'dig',
#   'deeper',
#   'debt',
#   'confidenti',
#   'oblig',
#   'free',
#   'quot',
#   'free',
#   'debt',
#   'consolid',
#   'quot',
#   'debt',
#   'train',
#   'profession',
#   'negoti',
#   'creditor',
#   'lower',
#   'monthli',
#   'debt',
#   'payment',
#   'end',
#   'creditor',
#   'harass',
#   'save',
#   'thousand',
#   'dollar',
#   'interest',
#   'late',
#   'charg',
#   'start',
#   'improv',
#   'credit',
#   'rate',
#   'complet',
#   'quickform',
#   'submit',
#   'free',
#   'analysi',
#   'name',
#   'street',
#   'address',
#   'citi',
#   'state',
#   'zip',
#   'alabama',
#   'alaska',
#   'arizona',
#   'arkansa',
#   'california',
#   'colorado',
#   'connecticut',
#   'delawar',
#   'dist',
#   'columbia',
#   'florida',
#   'georgia',
#   'hawaii',
#   'idaho',
#   'illinoi',
#   'indiana',
#   'iowa',
#   'kansa',
#   'kentucki',
#   'louisiana',
#   'main',
#   'maryland',
#   'massachusett',
#   'michigan',
#   'minnesota',
#   'mississippi',
#   'missouri',
#   'montana',
#   'nebraska',
#   'nevada',
#   'new',
#   'hampshir',
#   'new',
#   'jersey',
#   'new',
#   'mexico',
#   'new',
#   'york',
#   'north',
#   'carolina',
#   'north',
#   'dakota',
#   'ohio',
#   'oklahoma',
#   'oregon',
#   'pennsylvania',
#   'rhode',
#   'island',
#   'south',
#   'carolina',
#   'south',
#   'dakota',
#   'tennesse',
#   'texa',
#   'utah',
#   'vermont',
#   'virginia',
#   'washington',
#   'west',
#   'virginia',
#   'wisconsin',
#   'wyom',
#   'home',
#   'phone',
#   'area',
#   'code',
#   'work',
#   'phone',
#   'area',
#   'code',
#   'best',
#   'time',
#   'contact',
#   'morn',
#   'home',
#   'morn',
#   'work',
#   'afternoon',
#   'home',
#   'afternoon',
#   'work',
#   'even',
#   'home',
#   'even',
#   'work',
#   'weekend',
#   'email',
#   'address',
#   'total',
#   'debt',
#   'pleas',
#   'click',
#   'submit',
#   'button',
#   'process',
#   'take',
#   'second',
#   'pleas',
#   'repli',
#   'email',
#   'follow',
#   'free',
#   'analysi',
#   'name',
#   'address',
#   'citi',
#   'state',
#   'zip',
#   'home',
#   'phone',
#   'work',
#   'phone',
#   'best',
#   'time',
#   'email',
#   'total',
#   'debt',
#   'interest',
#   'pleas',
#   'send',
#   'email',
#   'mamrfitxhidjpfxo',
#   'http'],
#  ['hello',
#   'jm',
#   'growth',
#   'hormon',
#   'therapi',
#   'lose',
#   'weight',
#   'build',
#   'lean',
#   'muscl',
#   'massand',
#   'revers',
#   'ravag',
#   'age',
#   'remark',
#   'discoveri',
#   'human',
#   'growth',
#   'hormon',
#   'hgh',
#   'chang',
#   'way',
#   'think',
#   'age',
#   'weight',
#   'loss',
#   'lose',
#   'weightbuild',
#   'muscl',
#   'tonerevers',
#   'age',
#   'increas',
#   'libidodur',
#   'penil',
#   'erectionhealthi',
#   'bone',
#   'improv',
#   'memoryimprov',
#   'skinnew',
#   'hair',
#   'growthwrinkl',
#   'disappear',
#   'visit',
#   'web',
#   'site',
#   'learn',
#   'fact',
#   'click',
#   'herey',
#   'receiv',
#   'email',
#   'subscriberto',
#   'america',
#   'mail',
#   'list',
#   'remov',
#   'relat',
#   'maillist',
#   'click'],
#  ['welcom',
#   'viagra',
#   'express',
#   'http',
#   'object',
#   'viagra',
#   'express',
#   'simpl',
#   'want',
#   'provid',
#   'genuin',
#   'fda',
#   'approv',
#   'viagra',
#   'lowest',
#   'possibl',
#   'price',
#   'import',
#   'factor',
#   'set',
#   'us',
#   'apart',
#   'competit',
#   'confidenti',
#   'onlin',
#   'consult',
#   'global',
#   'physician',
#   'network',
#   'licens',
#   'physician',
#   'worldwid',
#   'hour',
#   'deliveri',
#   'upon',
#   'order',
#   'approv',
#   'simpli',
#   'lowest',
#   'price',
#   'order',
#   'approv',
#   'reason',
#   'discret',
#   'assur',
#   'satisfact',
#   'guarante',
#   'http',
#   'also',
#   'carri',
#   'product',
#   'weight',
#   'loss',
#   'hair',
#   'loss',
#   'product',
#   'iyri'],
#  ['dear',
#   'sir',
#   'mr',
#   'mariam',
#   'abacha',
#   'wife',
#   'late',
#   'nigerian',
#   'head',
#   'state',
#   'gener',
#   'sani',
#   'abacha',
#   'die',
#   'june',
#   'still',
#   'activ',
#   'duti',
#   'contact',
#   'view',
#   'fact',
#   'great',
#   'assist',
#   'likewis',
#   'develop',
#   'cordial',
#   'relationship',
#   'current',
#   'within',
#   'reach',
#   'sum',
#   'thirti',
#   'six',
#   'million',
#   'unit',
#   'state',
#   'dollar',
#   'us',
#   'cash',
#   'intend',
#   'use',
#   'invest',
#   'purpos',
#   'specif',
#   'countri',
#   'money',
#   'came',
#   'result',
#   'payback',
#   'contract',
#   'deal',
#   'late',
#   'husband',
#   'russian',
#   'firm',
#   'dollar',
#   'ajaokuta',
#   'steel',
#   'plant',
#   'russian',
#   'partner',
#   'return',
#   'husband',
#   'share',
#   'us',
#   'death',
#   'lodg',
#   'late',
#   'husband',
#   'secur',
#   'compani',
#   'nigeria',
#   'director',
#   'right',
#   'new',
#   'civilian',
#   'govern',
#   'intensifi',
#   'probe',
#   'husband',
#   'financi',
#   'resourc',
#   'revok',
#   'licens',
#   'allow',
#   'us',
#   'financi',
#   'oil',
#   'compani',
#   'view',
#   'act',
#   'fast',
#   'withdraw',
#   'us',
#   'compani',
#   'vault',
#   'deposit',
#   'privat',
#   'erect',
#   'secur',
#   'safe',
#   'abroad',
#   'record',
#   'ever',
#   'exist',
#   'concern',
#   'money',
#   'neither',
#   'money',
#   'traceabl',
#   'govern',
#   'document',
#   'show',
#   'receiv',
#   'money',
#   'russian',
#   'due',
#   'current',
#   'situat',
#   'countri',
#   'concern',
#   'govern',
#   'attitud',
#   'toward',
#   'famili',
#   'becom',
#   'quit',
#   'imposs',
#   'make',
#   'use',
#   'money',
#   'within',
#   'thu',
#   'seek',
#   'assist',
#   'transfer',
#   'money',
#   'safe',
#   'bank',
#   'account',
#   'consent',
#   'shall',
#   'expect',
#   'contact',
#   'urgent',
#   'enabl',
#   'us',
#   'discuss',
#   'detail',
#   'transact',
#   'bear',
#   'mind',
#   'assist',
#   'need',
#   'transfer',
#   'fund',
#   'propos',
#   'commiss',
#   'total',
#   'sum',
#   'expect',
#   'servic',
#   'assist',
#   'urgent',
#   'respons',
#   'highli',
#   'need',
#   'stop',
#   'contact',
#   'correspond',
#   'forward',
#   'email',
#   'call',
#   'son',
#   'mobil',
#   'hamza',
#   'use',
#   'opportun',
#   'implor',
#   'exercis',
#   'utmost',
#   'indulg',
#   'keep',
#   'matter',
#   'extra',
#   'ordinarili',
#   'confidenti',
#   'ever',
#   'decis',
#   'await',
#   'prompt',
#   'respons',
#   'best',
#   'person',
#   'regard',
#   'mr',
#   'mariam',
#   'abacha',
#   'deathtospamdeathtospamdeathtospam',
#   'email',
#   'sponsor',
#   'jabber',
#   'world',
#   'fastest',
#   'grow',
#   'commun',
#   'platform',
#   'im',
#   'build',
#   'http',
#   'mail',
#   'list',
#   'http'],
#  ['messag',
#   'mime',
#   'format',
#   'wish',
#   'unsubscrib',
#   'list',
#   'pleas',
#   'send',
#   'email',
#   'remov',
#   'remov',
#   'subject',
#   'line',
#   'call',
#   'us',
#   'write',
#   'us',
#   'st',
#   'petersburg',
#   'fl',
#   'lowest',
#   'mortgag',
#   'rate',
#   'america',
#   'easi',
#   'onlin',
#   'form',
#   'less',
#   'minut',
#   'complet',
#   'inform',
#   'pleas',
#   'go',
#   'http',
#   'rate',
#   'low',
#   'miss',
#   'opportun',
#   'good',
#   'bad',
#   'credit',
#   'ideal',
#   'time',
#   'purchas',
#   'home',
#   'refin',
#   'exist',
#   'mortgag',
#   'lower',
#   'current',
#   'payment',
#   'convert',
#   'adjust',
#   'rate',
#   'mortgag',
#   'arm',
#   'low',
#   'fix',
#   'loan',
#   'convert',
#   'arm',
#   'better',
#   'arm',
#   'convert',
#   'yr',
#   'mortgag',
#   'yr',
#   'mortgag',
#   'build',
#   'equiti',
#   'faster',
#   'need',
#   'cash',
#   'home',
#   'equiti',
#   'loan',
#   'rate',
#   'price',
#   'right',
#   'save',
#   'hundr',
#   'dollar',
#   'month',
#   'rate',
#   'great',
#   'miss',
#   'opportun',
#   'inform',
#   'pleas',
#   'go',
#   'http',
#   'sourc',
#   'lend',
#   'gen',
#   'wish',
#   'unsubscrib',
#   'list',
#   'pleas',
#   'click',
#   'send',
#   'email',
#   'address',
#   'call',
#   'us',
#   'write',
#   'us',
#   'st',
#   'petersburg',
#   'fl',
#   'rate',
#   'low',
#   'miss',
#   'opportun',
#   'good',
#   'bad',
#   'credit',
#   'ideal',
#   'time',
#   'purchas',
#   'home',
#   'refin',
#   'exist',
#   'mortgag',
#   'lower',
#   'current',
#   'payment',
#   'convert',
#   'adjust',
#   'rate',
#   'mortgag',
#   'arm',
#   'low',
#   'fix',
#   'loan',
#   'convert',
#   'arm',
#   'better',
#   'arm',
#   'convert',
#   'yr',
#   'mortgag',
#   'yr',
#   'mortgag',
#   'build',
#   'equiti',
#   'faster',
#   'need',
#   'cash',
#   'home',
#   'equiti',
#   'loan',
#   'rate',
#   'price',
#   'right',
#   'save',
#   'hundr',
#   'dollar',
#   'month',
#   'rate',
#   'great',
#   'miss'],
#  ['money',
#   'make',
#   'home',
#   'busi',
#   'copyright',
#   'right',
#   'reserv',
#   'address',
#   'verifi',
#   'one',
#   'request',
#   'inform',
#   'offer',
#   'address',
#   'doubl',
#   'verifi',
#   'messag',
#   'come',
#   'error',
#   'pleas',
#   'click',
#   'remov',
#   'name',
#   'remov',
#   'futur',
#   'mail'],
#  ['taken',
#   'mail',
#   'list',
#   'simpli',
#   'hit',
#   'repli',
#   'button',
#   'put',
#   'remov',
#   'anywher',
#   'subject',
#   'amateur',
#   'want',
#   'take',
#   'look',
#   'hardcor',
#   'site',
#   'young',
#   'hottt',
#   'teen',
#   'best',
#   'best',
#   'come',
#   'amateur',
#   'believ',
#   'take',
#   'look',
#   'amateur',
#   'petit',
#   'natur',
#   'tight',
#   'co',
#   'petit',
#   'natur',
#   'breast',
#   'amateur',
#   'exclus',
#   'amateur',
#   'xxx',
#   'video',
#   'hundr',
#   'exclus',
#   'petit',
#   'amateur',
#   'model',
#   'click',
#   'check',
#   'action',
#   'http',
#   'http',
#   'ampl',
#   'amateur',
#   'breast',
#   'women',
#   'men',
#   'love',
#   'men',
#   'women',
#   'old',
#   'adag',
#   'bigger',
#   'better',
#   'hold',
#   'true',
#   'find',
#   'plenti',
#   'hold',
#   'stabl',
#   'stack',
#   'exclus',
#   'ampl',
#   'amateur',
#   'make',
#   'mouth',
#   'water',
#   'hand',
#   'tire',
#   'look',
#   'http',
#   'http',
#   'amateur',
#   'smut',
#   'smuttiest',
#   'xxx',
#   'amateur',
#   'web',
#   'real',
#   'amateur',
#   'explicit',
#   'photo',
#   'shoot',
#   'high',
#   'qualiti',
#   'smut',
#   'pic',
#   'pic',
#   'horni',
#   'girl',
#   'next',
#   'door',
#   'nasti',
#   'amateur',
#   'gone',
#   'wild',
#   'http',
#   'http',
#   'taken',
#   'mail',
#   'list',
#   'simpli',
#   'hit',
#   'repli',
#   'button',
#   'put',
#   'remov',
#   'anywher',
#   'subject'],
#  ['result',
#   'feedback',
#   'form',
#   'submit',
#   'xcutieamandax',
#   'tuesday',
#   'juli',
#   'want',
#   'big',
#   'peni',
#   'experi',
#   'result',
#   'alway',
#   'want',
#   'massiv',
#   'scientif',
#   'breakthrough',
#   'pill',
#   'actual',
#   'expand',
#   'lengthen',
#   'enlarg',
#   'peni',
#   'guarante',
#   'best',
#   'agon',
#   'hang',
#   'weight',
#   'tough',
#   'exercis',
#   'pain',
#   'pump',
#   'danger',
#   'surgeri',
#   'involv',
#   'guarante',
#   'genuin',
#   'last',
#   'result',
#   'pill',
#   'work',
#   'get',
#   'money',
#   'back',
#   'click',
#   'give',
#   'tri',
#   'one',
#   'best',
#   'invest',
#   'ever',
#   'made',
#   'even',
#   'begin',
#   'express',
#   'much',
#   'gratitud',
#   'product',
#   'even',
#   'first',
#   'bottl',
#   'alreadi',
#   'grown',
#   'length',
#   'girth',
#   'still',
#   'anoth',
#   'bottl',
#   'go',
#   'averag',
#   'inch',
#   'guy',
#   'http'],
#  ['mortgag',
#   'search',
#   'got',
#   'win',
#   'mortgag',
#   'tri',
#   'get',
#   'mortgag',
#   'rate',
#   'littl',
#   'cash',
#   'pocket',
#   'know',
#   'tell',
#   'truth',
#   'solv',
#   'problem',
#   'visit',
#   'site',
#   'today',
#   'two',
#   'minut',
#   'us',
#   'search',
#   'thousand',
#   'program',
#   'lender',
#   'get',
#   'truth',
#   'get',
#   'fact',
#   'get',
#   'option',
#   'one',
#   'shot',
#   'absolut',
#   'free',
#   'done',
#   'two',
#   'minut',
#   'click',
#   'right',
#   'put',
#   'worri',
#   'behind',
#   'kj'],
#  ['hello',
#   'jlnax',
#   'human',
#   'growth',
#   'hormon',
#   'therapi',
#   'lose',
#   'weight',
#   'build',
#   'lean',
#   'muscl',
#   'massand',
#   'revers',
#   'ravag',
#   'age',
#   'remark',
#   'discoveri',
#   'human',
#   'growth',
#   'hormon',
#   'hgh',
#   'chang',
#   'way',
#   'think',
#   'age',
#   'weight',
#   'loss',
#   'lose',
#   'weight',
#   'build',
#   'muscl',
#   'tone',
#   'revers',
#   'age',
#   'increas',
#   'libido',
#   'durat',
#   'penil',
#   'erect',
#   'healthier',
#   'bone',
#   'improv',
#   'memori',
#   'improv',
#   'skin',
#   'new',
#   'hair',
#   'growth',
#   'wrinkl',
#   'disappear',
#   'visit',
#   'web',
#   'site',
#   'learn',
#   'fact',
#   'click',
#   'receiv',
#   'email',
#   'subscriberto',
#   'america',
#   'mail',
#   'list',
#   'remov',
#   'relat',
#   'maillist',
#   'click'],
#  ['want',
#   'make',
#   'million',
#   'buck',
#   'year',
#   'probabl',
#   'go',
#   'happen',
#   'howev',
#   'look',
#   'opportun',
#   'make',
#   'coupl',
#   'thousand',
#   'week',
#   'work',
#   'form',
#   'home',
#   'pc',
#   'need',
#   'talk',
#   'us',
#   'resid',
#   'click',
#   'repli',
#   'send',
#   'name',
#   'state',
#   'complet',
#   'telephon',
#   'number',
#   'best',
#   'time',
#   'contact',
#   'person',
#   'speak',
#   'within',
#   'hour',
#   'remov',
#   'mail',
#   'list',
#   'pleas',
#   'type',
#   'remov',
#   'subject',
#   'column',
#   'http'],
#  ['jcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqncklmihlv',
#   'jcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqkjcqn',
#   'deathtospamdeathtospamdeathtospam',
#   'email',
#   'sponsor',
#   'jabber',
#   'world',
#   'fastest',
#   'grow',
#   'commun',
#   'platform',
#   'im',
#   'build',
#   'http',
#   'mail',
#   'list',
#   'http'],
#  ['new',
#   'vigor',
#   'herbal',
#   'love',
#   'enhanc',
#   'new',
#   'straight',
#   'om',
#   'lab',
#   'offer',
#   'new',
#   'ly',
#   'formul',
#   'natur',
#   'product',
#   'help',
#   'stimul',
#   'moment',
#   'special',
#   'someon',
#   'e',
#   'excit',
#   'love',
#   'make',
#   'experi',
#   'ever',
#   'vigor',
#   'hand',
#   'nbsp',
#   'sp',
#   'ricardo',
#   'isabel',
#   'la',
#   'vega',
#   'nv',
#   'super',
#   'vigoralfor',
#   'men',
#   'super',
#   'vigorettefor',
#   'women',
#   'uper',
#   'everyon',
#   'get',
#   'free',
#   'ship',
#   'time',
#   'click',
#   'order',
#   'email',
#   'address',
#   'obtain',
#   'list',
#   'mrsa',
#   'list',
#   'purchas',
#   'code',
#   'wish',
#   'unsubscrib',
#   'list',
#   'pleas',
#   'click',
#   'press',
#   'send',
#   'remov',
#   'previous',
#   'unsubscrib',
#   'still',
#   'receiv',
#   'messag',
#   'may',
#   'email',
#   'abus',
#   'control',
#   'center',
#   'condon',
#   'spam',
#   'shape',
#   'form',
#   'nk',
#   'kindli',
#   'cooper',
#   'free',
#   'ship',
#   'order',
#   'three',
#   'product',
#   'deathtospamdeathtospamdeathtospam',
#   'email',
#   'sponsor',
#   'thinkgeek',
#   'welcom',
#   'geek',
#   'heaven',
#   'http',
#   'mail',
#   'list',
#   'http'],
#  ['got',
#   'webcam',
#   'comput',
#   'birthday',
#   'finish',
#   'first',
#   'homepag',
#   'ad',
#   'model',
#   'pictur',
#   'think',
#   'help',
#   'career',
#   'pleas',
#   'let',
#   'know',
#   'could',
#   'also',
#   'use',
#   'opinion',
#   'make',
#   'site',
#   'look',
#   'better',
#   'ca',
#   'help',
#   'know',
#   'someon',
#   'pleas',
#   'forward',
#   'need',
#   'money',
#   'sure',
#   'use',
#   'work',
#   'ad',
#   'recent',
#   'set',
#   'pictur',
#   'want',
#   'look',
#   'pic',
#   'blond',
#   'hair',
#   'blue',
#   'eye',
#   'play',
#   'volleybal',
#   'link',
#   'site',
#   'http',
#   'thank',
#   'juli',
#   'oh',
#   'know',
#   'sent',
#   'mistak',
#   'pleas',
#   'disregard',
#   'would',
#   'like',
#   'make',
#   'sure',
#   'remov',
#   'address',
#   'book',
#   'pleas',
#   'click',
#   'http',
#   'program',
#   'make',
#   'sure',
#   'send',
#   'ever',
#   'tri',
#   'talk'],
#  ...]

# %%
word_columns_df = pd.DataFrame.from_records(stemmed_nested_list.tolist())
word_columns_df.head()
# Out:
#        0       1       2        3       4          5         6       7     \
# 0  interest    rate     cut  perfect    time      think  refinanc    home
# 1      None    None    None     None    None       None      None    None
# 2      copi     dvd  burner      dvd  wizard  technolog    advanc  method
# 3    import  domain  inform      new  domain       name     final   avail
# 4      free    info    free    insid   stock     market    report    valu
#
#       8          9     ...  7661  7662  7663  7664  7665  7666  7667  7668  \
# 0  mortgag       rate  ...  None  None  None  None  None  None  None  None
# 1     None       None  ...  None  None  None  None  None  None  None  None
# 2      dvd  reproduct  ...  None  None  None  None  None  None  None  None
# 3    gener     public  ...  None  None  None  None  None  None  None  None
# 4      get     latest  ...  None  None  None  None  None  None  None  None
#
#    7669  7670
# 0  None  None
# 1  None  None
# 2  None  None
# 3  None  None
# 4  None  None
#
# [5 rows x 7671 columns]

# %%
word_columns_df.shape
# Out:
# (5796, 7671)

# %% [markdown]
# ### Splitting the Data into a Training and Testing Dataset

# %%
# Challenge: Can you split the data into a training and testing set? Set the test size at 30%. 
# The training data should include 4057 emails. Use a seed value of 42 to shuffle the data. 
# What should the target values be?

# %%
X_train, X_test, y_train, y_test = train_test_split(word_columns_df, data.CATEGORY,
                                                   test_size=0.3, random_state=42)

# %%
print('Nr of training samples', X_train.shape[0])
print('Fraction of training set', X_train.shape[0] / word_columns_df.shape[0])
# Out:
# Nr of training samples 4057
# Fraction of training set 0.6999654934437544

# %%
X_train.shape
# Out:
# (4057, 7671)

# %%
y_test.shape
# Out:
# (1739,)

# %%
X_train.head()
# Out:
#         0        1       2       3        4       5      6         7     \
# 4844      hi   debian  machin  extern     isdn  termin  adapt       tri
# 4727    theo      van  dinter   wrote      wed     aug  frank    pineau
# 5022  joseph  barrera     iii     use  version   opera   mean      half
# 3504      jh    legal  requir     got  similar   check     jh     insur
# 3921     url     http    date  suppli    damag    form  newli  identifi
#
#          8       9     ...  7661  7662  7663  7664  7665  7666  7667  7668  \
# 4844      get    dial  ...  None  None  None  None  None  None  None  None
# 4727    wrote   omaha  ...  None  None  None  None  None  None  None  None
# 5022     page    look  ...  None  None  None  None  None  None  None  None
# 3504  compani     pay  ...  None  None  None  None  None  None  None  None
# 3921     gene  implic  ...  None  None  None  None  None  None  None  None
#
#       7669  7670
# 4844  None  None
# 4727  None  None
# 5022  None  None
# 3504  None  None
# 3921  None  None
#
# [5 rows x 7671 columns]

# %%
X_train.index.name = X_test.index.name = 'DOC_ID'
X_train.head()
# Out:
#           0        1       2       3        4       5      6         7     \
# DOC_ID
# 4844        hi   debian  machin  extern     isdn  termin  adapt       tri
# 4727      theo      van  dinter   wrote      wed     aug  frank    pineau
# 5022    joseph  barrera     iii     use  version   opera   mean      half
# 3504        jh    legal  requir     got  similar   check     jh     insur
# 3921       url     http    date  suppli    damag    form  newli  identifi
#
#            8       9     ...  7661  7662  7663  7664  7665  7666  7667  7668  \
# DOC_ID                   ...
# 4844        get    dial  ...  None  None  None  None  None  None  None  None
# 4727      wrote   omaha  ...  None  None  None  None  None  None  None  None
# 5022       page    look  ...  None  None  None  None  None  None  None  None
# 3504    compani     pay  ...  None  None  None  None  None  None  None  None
# 3921       gene  implic  ...  None  None  None  None  None  None  None  None
#
#         7669  7670
# DOC_ID
# 4844    None  None
# 4727    None  None
# 5022    None  None
# 3504    None  None
# 3921    None  None
#
# [5 rows x 7671 columns]

# %%
y_train.head()
# Out:
# DOC_ID
# 4844    0
# 4727    0
# 5022    0
# 3504    0
# 3921    0
# Name: CATEGORY, dtype: int64

# %% [markdown]
# ### Create a Sparse Matrix for the Training Data

# %%
# stemmed_nested_list = data.MESSAGE.apply(clean_msg_no_html)
# flat_stemmed_list = [item for sublist in stemmed_nested_list for item in sublist]
# unique_words = pd.Series(flat_stemmed_list).value_counts()
# frequent_words = unique_words[0:2500]

# %%
word_ids = list(range(0, 2500))
vocab = pd.DataFrame({'VOCAB_WORD': frequent_words.index.values}, index=word_ids)
vocab.index.name = 'WORD_ID'
vocab.head()
# Out:
#         VOCAB_WORD
# WORD_ID
# 0             http
# 1              use
# 2             list
# 3            email
# 4              get

# %%
word_index = pd.Index(vocab.VOCAB_WORD)
type(word_index[3])
# Out:
# str

# %%
word_index.get_loc('thu')
# Out:
# 395

# %%
def make_sparse_matrix(df, indexed_words, labels):
    """
    Returns sparse matrix as dataframe.
    
    df: A dataframe with words in the columns with a document id as an index (X_train or X_test)
    indexed_words: index of words ordered by word id
    labels: category as a series (y_train or y_test)
    """
    
    nr_rows = df.shape[0]
    nr_cols = df.shape[1]
    word_set = set(indexed_words)
    dict_list = []
    
    for i in range(nr_rows):
        for j in range(nr_cols):
            
            word = df.iat[i, j]
            if word in word_set:
                doc_id = df.index[i]
                word_id = indexed_words.get_loc(word)
                category = labels.at[doc_id]
                
                item = {'LABEL': category, 'DOC_ID': doc_id,
                       'OCCURENCE': 1, 'WORD_ID': word_id}
                
                dict_list.append(item)
    
    return pd.DataFrame(dict_list)

# %%
sparse_train_df = make_sparse_matrix(X_train, word_index, y_train)

# %%
sparse_train_df[:5]
# Out:
#    DOC_ID  LABEL  OCCURENCE  WORD_ID
# 0    4844      0          1      531
# 1    4844      0          1     1945
# 2    4844      0          1      468
# 3    4844      0          1     1641
# 4    4844      0          1     1487

# %%
sparse_train_df.shape
# Out:
# (449250, 4)

# %%
sparse_train_df[-5:]
# Out:
#         DOC_ID  LABEL  OCCURENCE  WORD_ID
# 449245     860      1          1      250
# 449246     860      1          1        0
# 449247     860      1          1        5
# 449248     860      1          1        2
# 449249     860      1          1        0

# %% [markdown]
# ### Combine Occurrences with the Pandas groupby() Method

# %%
train_grouped = sparse_train_df.groupby(['DOC_ID', 'WORD_ID', 'LABEL']).sum()
train_grouped.head()
# Out:
#                       OCCURENCE
# DOC_ID WORD_ID LABEL
# 0      0       1              2
#        8       1              1
#        18      1              1
#        26      1              1
#        28      1              2

# %%
vocab.at[0, 'VOCAB_WORD']
# Out:
# 'http'

# %%
data.MESSAGE[0]
# Out:
# "INTEREST RATES HAVE JUST BEEN CUT!!!\n\n     \n\nNOW is the perfect time to think about refinancing your home mortgage! Rates are down! Take a minute and fill out our quick online form. \n\nhttp://www.newnamedns.com/refi/\n\n           \n\nEasy qualifying, prompt, courteous service, low rates! Don't wait for interest rates to go up again, lock in YOUR low rate now!\n\n          \n\n          \n\n          \n\n         \n\n          \n\n        \n\n---------------------------------------\n\nTo unsubscribe, go to: \n\nhttp://www.newnamedns.com/stopthemailplease/\n\nPlease allow 48-72 hours for removal.\n\n\n"

# %%
train_grouped = train_grouped.reset_index()
train_grouped.head()
# Out:
#    DOC_ID  WORD_ID  LABEL  OCCURENCE
# 0       0        0      1          2
# 1       0        8      1          1
# 2       0       18      1          1
# 3       0       26      1          1
# 4       0       28      1          2

# %%
train_grouped.tail()
# Out:
#         DOC_ID  WORD_ID  LABEL  OCCURENCE
# 266539    5795      509      0          2
# 266540    5795      792      0          2
# 266541    5795      806      0          2
# 266542    5795     1647      0          3
# 266543    5795     1649      0          2

# %%
vocab.at[1923, 'VOCAB_WORD']
# Out:
# 'exclud'

# %%
data.MESSAGE[5795]
# Out:
# 'This is a multi-part message in MIME format.\n\n\n\n------=_NextPart_000_0005_01C2291D.98A2ED40\n\nContent-Type: text/plain;\n\n\tcharset="iso-8859-1"\n\nContent-Transfer-Encoding: quoted-printable\n\n\n\nActresses with just the one annoying accent! Don\'t we all just love =\n\nthem? Them and football of course, more of which in the Breaking News =\n\nsection of your friendly neighbourhood Evil Gerald.\n\n\n\nYours,\n\n\n\nThe Evil Gerald=20\n\n\n\n------=_NextPart_000_0005_01C2291D.98A2ED40\n\nContent-Type: text/html;\n\n\tcharset="iso-8859-1"\n\nContent-Transfer-Encoding: quoted-printable\n\n\n\n<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">\n\n<HTML><HEAD>\n\n<META content=3D"text/html; charset=3Diso-8859-1" =\n\nhttp-equiv=3DContent-Type>\n\n<META content=3D"MSHTML 5.00.2919.6307" name=3DGENERATOR>\n\n<STYLE></STYLE>\n\n</HEAD>\n\n<BODY bgColor=3D#ffffff>\n\n<DIV><FONT face=3DArial size=3D2>Actresses with just the one annoying =\n\naccent! Don\'t=20\n\nwe all just love them? Them and football of course, more of which in the =\n\n<A=20\n\nhref=3D"http://www.evilgerald.com/Breaking_news.htm">Breaking News</A> =\n\nsection of=20\n\nyour friendly neighbourhood <A href=3D"http://www.evilgerald.com">Evil=20\n\nGerald</A>.</FONT></DIV>\n\n<DIV>&nbsp;</DIV>\n\n<DIV><FONT face=3DArial size=3D2>Yours,</FONT></DIV>\n\n<DIV>&nbsp;</DIV>\n\n<DIV><FONT face=3DArial size=3D2>The Evil Gerald =\n\n</FONT></DIV></BODY></HTML>\n\n\n\n------=_NextPart_000_0005_01C2291D.98A2ED40--\n\n\n\n\n\n\n'

# %%
train_grouped.shape
# Out:
# (266544, 4)

# %% [markdown]
# ### Save Training Data as .txt File

# %%
np.savetxt(TRAINING_DATA_FILE, train_grouped, fmt='%d')

# %%
train_grouped.columns
# Out:
# Index(['DOC_ID', 'WORD_ID', 'LABEL', 'OCCURENCE'], dtype='object')

# %% [markdown]
# # Challenge
#
# Can you create a sparse matrix for the test data. Group the occurrences of the same word in the same email. Then save the data as a .txt file.

# %%
X_test.head()
# Out:
#           0        1          2        3         4          5          6     \
# DOC_ID
# 4675    messag     mime     format   comput      game       http  wednesday
# 4220      read     rest       look     quit      good       seem        odd
# 2484      upon     time        dtd    wrote     thank      great       work
# 2418       hey  problem        rpm   instal      want   uninstal       like
# 5110       tue      aug  wintermut  mention  unimagin  difficult        far
#
#           7      8          9     ...  7661  7662  7663  7664  7665  7666  \
# DOC_ID                            ...
# 4675      juli    gmt      space  ...  None  None  None  None  None  None
# 4220     would   make  seemingli  ...  None  None  None  None  None  None
# 2484    mathia  would       like  ...  None  None  None  None  None  None
# 2418       rpm    rpm     packag  ...  None  None  None  None  None  None
# 5110      know  linux     kernel  ...  None  None  None  None  None  None
#
#         7667  7668  7669  7670
# DOC_ID
# 4675    None  None  None  None
# 4220    None  None  None  None
# 2484    None  None  None  None
# 2418    None  None  None  None
# 5110    None  None  None  None
#
# [5 rows x 7671 columns]

# %%
y_test.head()
# Out:
# DOC_ID
# 4675    0
# 4220    0
# 2484    0
# 2418    0
# 5110    0
# Name: CATEGORY, dtype: int64

# %%
X_test.shape
# Out:
# (1739, 7671)

# %%
sparse_test_df = make_sparse_matrix(X_test, word_index, y_test)

# %%
sparse_test_df.shape
# Out:
# (184883, 4)

# %%
test_grouped = sparse_test_df.groupby(['DOC_ID', 'WORD_ID', 'LABEL']).sum().reset_index()
test_grouped.head()
# Out:
#    DOC_ID  WORD_ID  LABEL  OCCURENCE
# 0      12        0      1          1
# 1      12        2      1          2
# 2      12        3      1          4
# 3      12        5      1          2
# 4      12       10      1          1

# %%
test_grouped.shape
# Out:
# (109420, 4)

# %%
np.savetxt(TEST_DATA_FILE, test_grouped, fmt='%d')

# %% [markdown]
# # Pre-Processing Subtleties and Checking your Understanding

# %% [markdown]
# Challenge: We started with 5796 emails. We split it into 4057 emails for training and 1739 emails for testing.
#
# How many individual emails were included in the testing .txt file? Count the number in the test_grouped DataFrame. After splitting and shuffling our data, how many emails were included in the X_test DataFrame? Is the number the same? If not, which emails were excluded and why? Compare the DOC_ID values to find out.

# %%
train_doc_ids = set(train_grouped.DOC_ID)
test_doc_ids = set(test_grouped.DOC_ID)

# %%
len(test_doc_ids)
# Out:
# 1715

# %%
len(X_test)
# Out:
# 1739

# %%
set(X_test.index.values) - test_doc_ids # Excluded emails after pre-processing
# Out:
# {8,
#  88,
#  100,
#  122,
#  139,
#  156,
#  195,
#  214,
#  295,
#  300,
#  450,
#  463,
#  485,
#  497,
#  642,
#  654,
#  693,
#  828,
#  927,
#  1044,
#  1084,
#  1338,
#  1662,
#  1831}

# %%
data.MESSAGE[14]
# Out:
# '<html>\n\n<head>\n\n<title></title>\n\n</head>\n\n<body bgcolor=3D"#FFFFFF">\n\n\n\n<table width=3D500 cellpadding=3D10 border=3D0><tr>\n\n<td><font  face=3D"bankgothic, western" color=3D"#6600FF" \n\nsize=3D5><p><b>\n\n<a\n\nhref=3D"http://www.herbs4you.net/?id=3D609">\n\nMother Natures all Natural Marital Aid<br> for Men and\n\nWomen - Your\'s Risk Free!</b></p></font>\n\n<font face=3D"arial black" color=3D"#000000" size=3D3><p>The\n\nall natural safe formula for men and women your\'s risk\n\nfree for 30 days. Mother Nature\'s wonder pill of the\n\n21st century.<p>\n\n<li>Increased Sensation</li><br><li>Increased\n\nFrequency</li><br>\n\n<li>Increased Pleasure</li><br><li>Increased\n\nDesire</li><br>\n\n<li>Increased Stamina</li><br><li>Increased\n\nLibido</li></font><br><br>\n\nBoth male and female formulas!<br><p><body\n\nbgcolor=3D"#FFFFFF">\n\nOrder Your  Trial Today !</a></p></font>\n\n</td></tr></table>\n\n<table width=3D500 cellpadding=3D10 border=3D0><tr><td>\n\n<font face=3Darial size=3D1.5><br><br><br><p>to depart\n\nfrom further contacts\n\n<a\n\nhref=3D"http://www.herbs4you.net/service.html">visit\n\nhere</a></p></font>\n\n</td></tr></table>\n\n</body>\n\n</html>\n\ntbeyer\n\n\n\n\n\n\n\n\n\n\n\n\n'

# %%
data.loc[14]
# Out:
# CATEGORY                                                     1
# MESSAGE      <html>\n\n<head>\n\n<title></title>\n\n</head>...
# FILE_NAME               00176.79f82496c612ea28f45f13ca5c47f8c2
# Name: 14, dtype: object

# %%
clean_msg_no_html(data.at[14, 'MESSAGE'])
# Out:
# ['mother',
#  'natur',
#  'natur',
#  'marit',
#  'aid',
#  'men',
#  'women',
#  'risk',
#  'free',
#  'natur',
#  'safe',
#  'formula',
#  'men',
#  'women',
#  'risk',
#  'free',
#  'day',
#  'mother',
#  'natur',
#  'wonder',
#  'pill',
#  'centuri',
#  'increas',
#  'sensationincreas',
#  'frequenc',
#  'increas',
#  'pleasureincreas',
#  'desir',
#  'increas',
#  'staminaincreas',
#  'libido',
#  'male',
#  'femal',
#  'formula',
#  'order',
#  'trial',
#  'today',
#  'depart',
#  'contact',
#  'visit',
#  'tbeyer']

# %%
data.MESSAGE[1096]
# Out:
# 'Finally: After 15 Years of Research and Development..A True WEIGHT LOSS Breakthrough Years Ahead of it\'s Time! \n\n\n\nSERIOUSLY: DEEP DOWN YOU KNOW THAT MILLIONAIRES ARE MADE BY GETTING INVOLVED IN OPPORTUNITIES BEFORE THE GENERAL PUBLIC FINDS OUT...HERE IS YOUR CHANCE TO GET INVOLVED WITH A PRODUCT THAT CAN LEAD TO SERIOUS, MONTHLY RESIDUAL INCOME (Do the work once and keep getting paid!)...FIND OUT WHY...FIND OUT HOW...NOW!\n\n\n\nSend a blank email with the words "SUBSCRIBE to T.E.D" in the subject area to:\n\n\n\njmpro@hotpop.com\n\n\n\nThis is your first step towards working with a team of 7 figure income earners that can teach you how to do the same because of a proven system that will be customized for you!\n\n\n\n\n\nmmuocfvfbxotxknbnbdytkwdbonvovyv\n'

# %%
clean_msg_no_html(data.at[1096, 'MESSAGE'])
# Out:
# ['final',
#  'year',
#  'research',
#  'true',
#  'weight',
#  'loss',
#  'breakthrough',
#  'year',
#  'ahead',
#  'time',
#  'serious',
#  'deep',
#  'know',
#  'millionair',
#  'made',
#  'get',
#  'involv',
#  'opportun',
#  'gener',
#  'public',
#  'find',
#  'chanc',
#  'get',
#  'involv',
#  'product',
#  'lead',
#  'seriou',
#  'monthli',
#  'residu',
#  'incom',
#  'work',
#  'keep',
#  'get',
#  'paid',
#  'find',
#  'find',
#  'send',
#  'blank',
#  'email',
#  'word',
#  'subscrib',
#  'subject',
#  'area',
#  'jmpro',
#  'first',
#  'step',
#  'toward',
#  'work',
#  'team',
#  'figur',
#  'incom',
#  'earner',
#  'teach',
#  'proven',
#  'system',
#  'custom',
#  'mmuocfvfbxotxknbnbdytkwdbonvovyv']

# %%
clean_message(data.at[1096, 'MESSAGE'])
# Out:
# ['final',
#  'year',
#  'research',
#  'true',
#  'weight',
#  'loss',
#  'breakthrough',
#  'year',
#  'ahead',
#  'time',
#  'serious',
#  'deep',
#  'know',
#  'millionair',
#  'made',
#  'get',
#  'involv',
#  'opportun',
#  'gener',
#  'public',
#  'find',
#  'chanc',
#  'get',
#  'involv',
#  'product',
#  'lead',
#  'seriou',
#  'monthli',
#  'residu',
#  'incom',
#  'work',
#  'keep',
#  'get',
#  'paid',
#  'find',
#  'find',
#  'send',
#  'blank',
#  'email',
#  'word',
#  'subscrib',
#  'subject',
#  'area',
#  'jmpro',
#  'first',
#  'step',
#  'toward',
#  'work',
#  'team',
#  'figur',
#  'incom',
#  'earner',
#  'teach',
#  'proven',
#  'system',
#  'custom',
#  'mmuocfvfbxotxknbnbdytkwdbonvovyv']
